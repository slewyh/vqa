# %%
# For CS6240 paper
# This is proof-of-concept (PoC) implementation for the extension of "Incorporating a Generative answer model in GQA" in the paper
# Done by Group 3 (Ma Xiaoping, Stephanie Lew)

# This python notebook has been tested in Google Colab only.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %tensorflow_version 1.x
# specify tensorflow version
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %%
# global variables

# maximum number of words, which determines the size of the vector representation of a word
MAX_NUM_WORDS = 3200

# For words that are not in the top MAX_NUM_WORDS
NULLTOKEN = "NULLTOKEN"

MAX_QUESTION_LENGTH=25
MAX_ANSWER_LENGTH=10

# VQA V2 existing features (downloaded from https://github.com/MILVLG/mcan-vqa)
MEDIA_FEATURE_DIMENSION = 2048
MEDIA_MAX_LENGTH = 70

# Question type
QUESTION_TYPE_DIMENSION = 65
MAX_QUESTION_TYPE_LENGTH = 1


# a buffer to store images to save loading time
# MAX_IMAGE_BUFFER_SIZE = 10000
MAX_IMAGE_BUFFER_SIZE = 20000

try:
  print (len(image_data_buffer))
except NameError as e:
  # init the buffer only if it is not init before
  image_data_buffer = {}

# num of candidate answers to be generated
NUM_CANDIDATE_ANSWERS = 50

# %%
# prepare data
# vaq v2, the original questions and answers can be downloaded from: https://visualqa.org/download.html

# follow https://machinelearningmastery.com/prepare-text-data-deep-learning-keras/ to preprocess text data

import json
import os
import pprint
import pandas as pd
import re

main_path = "/content/gdrive/My Drive/cs6240_project_codes/"
output_path = os.path.join(main_path, "outputs")

data_main_path = os.path.join(main_path, "data/vqa_v2/")

question_train_file = os.path.join(data_main_path, "v2_OpenEnded_mscoco_train2014_questions.json")
# load questions to a dictionary

with open(question_train_file) as f:
  questions = json.load(f)

qlist = questions["questions"]
qindex_example = 9
print ("qlist[{}] = {}".format(qindex_example, qlist[qindex_example]))
qid_example = qlist[9]['question_id']
# one example in qlist: qlist[9] = {'image_id': 524291, 'question': 'Is the dog looking at a tennis ball or frisbee?', 'question_id': 524291002}

print ("len(qlist) = {}".format(len(qlist)))

answer_train_file = os.path.join(data_main_path, "v2_mscoco_train2014_annotations.json")
# load answers to a dictionary, need to extract the answers and free it to save memory

with open(answer_train_file) as f:
  answers = json.load(f)

alist = answers["annotations"]

for i in range(len(alist)):
  if alist[i]['question_id'] == qid_example:
    pprint.pprint(alist[i])
    aindex = i
    break

for ans in alist:
  del ans['answers']

# remove 'answers' and keep 'multiple_choice_answer'
print ("alist[aindex] = {}".format(alist[aindex]))

def get_text_len(s):
	# the count includes punctuation marks
	return len(re.findall(r"[\w']+|[.,!?;]", s))
 
qdict = {}
question_lenths = []
for question in qlist:
	qdict[question['question_id']] = question
	question_lenths.append(get_text_len(question['question']))
print ("len(qlist) = {}, len(qdict) = {}".format(len(qlist), len(qdict)))

question_lenths.sort()
print ("the maximum question length is ", question_lenths[-1])
for p in [0.7, 0.8, 0.9, 0.95, 0.99, 0.999]:
	print ("the {} percentile question length is {}".format( p*100, question_lenths[ int(len(question_lenths) * p)]))
question_lenths = None

adict = {}
answer_lenths = []
for ans in alist:
	adict[ans['question_id']] = ans
	answer_lenths.append(get_text_len(ans['multiple_choice_answer']))
print ("len(alist) = {}, len(adict) = {}".format(len(alist), len(adict)))
answer_lenths.sort()
print ("the maximum answer length is ", answer_lenths[-1])
for p in [0.7, 0.8, 0.9, 0.95, 0.99, 0.999]:
	print ("the {} percentile answer length is {}".format( p*100, answer_lenths[ int(len(answer_lenths) * p)]))
answer_lenths = None

#def append_startword_endword_to_sentence(s):
#  return "{} {} {}".format(SENTENCE_START, s, SENTENCE_END)

qa_dict = {'question_id':[], 'question':[], 'answer':[], 'image_id':[], 'question_type':[], 'answer_type':[]}
for k in qdict.keys():
	# qa_dict[k] = {'question': qdict[k], 'answer': adict[k]}
	assert(k == qdict[k]['question_id'])
	assert(k == adict[k]['question_id'])
	qa_dict['question_id'].append(k)
	#qa_dict['question'].append(append_startword_endword_to_sentence(qdict[k]['question']))
	#qa_dict['answer'].append(append_startword_endword_to_sentence(adict[k]['multiple_choice_answer']))
	qa_dict['question'].append(qdict[k]['question'])
	qa_dict['answer'].append(adict[k]['multiple_choice_answer'])
	qa_dict['image_id'].append(qdict[k]['image_id'])
	qa_dict['question_type'].append(adict[k]['question_type'])
	qa_dict['answer_type'].append(adict[k]['answer_type'])

print ("len(qa_dict['question_id']) = {}".format(len(qa_dict['question_id'])))

qa_df = pd.DataFrame.from_dict(qa_dict)
print ("qa_df.shape = {}".format(qa_df.shape))
print ("qa_df.iloc[0] =\n{}".format(qa_df.iloc[0]))
# Out:
# qlist[9] = {'image_id': 524291, 'question': 'Is the dog looking at a tennis ball or frisbee?', 'question_id': 524291002}
# len(qlist) = 443757
# {'answer_type': 'other',
#  'answers': [{'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 1},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 2},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 3},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 4},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 5},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 6},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 7},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 8},
#              {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 9},
#              {'answer': 'frisbee',
#               'answer_confidence': 'yes',
#               'answer_id': 10}],
#  'image_id': 524291,
#  'multiple_choice_answer': 'frisbee',
#  'question_id': 524291002,
#  'question_type': 'is the'}
# alist[aindex] = {'question_type': 'is the', 'multiple_choice_answer': 'frisbee', 'image_id': 524291, 'answer_type': 'other', 'question_id': 524291002}
# len(qlist) = 443757, len(qdict) = 443757
# the maximum question length is  23
# the 70.0 percentile question length is 8
# the 80.0 percentile question length is 9
# the 90.0 percentile question length is 10
# the 95.0 percentile question length is 11
# the 99.0 percentile question length is 13
# the 99.9 percentile question length is 18
# len(alist) = 443757, len(adict) = 443757
# the maximum answer length is  19
# the 70.0 percentile answer length is 1
# the 80.0 percentile answer length is 1
# the 90.0 percentile answer length is 1
# the 95.0 percentile answer length is 2
# the 99.0 percentile answer length is 3
# the 99.9 percentile answer length is 5
# len(qa_dict['question_id']) = 443757
# qa_df.shape = (443757, 6)
# qa_df.iloc[0] =
# question_id                                      458752000
# question         What is this photo taken looking through?
# answer                                                 net
# image_id                                            458752
# question_type                                 what is this
# answer_type                                          other
# Name: 0, dtype: object

# %%
import pickle
import os

file_qtypes_saved_before = os.path.join(data_main_path, "question_types_saved.pickle")

with open(file_qtypes_saved_before, 'rb') as f:
  qt_dict = pickle.load(f)

# create a reversed dictionary for convienence for converting an index back to qtype
qt_reversed_dict = {}
for t, i in qt_dict.items():
  qt_reversed_dict[i] = t
assert (len(qt_reversed_dict) == len(qt_dict))

qtypes = qt_dict.keys()
print ("number of unique question types = {}".format(len(qtypes)))
print ("qtypes = ", qtypes)
print ("qt_dict = ", qt_dict)
assert (len(qt_dict) == QUESTION_TYPE_DIMENSION)

# checking only
qtypes_cur = list(set(qa_df["question_type"]))
print ("len(qtypes_cur) = {}".format(len(qtypes_cur)))

# make sure every qtype from qtypes_cur is in qtypes
for t in qtypes_cur:
  assert(t in qt_dict)

qtypes_cur = None # free it in case it is accidentally used


def get_one_hot_representation_qtype(qtype_df):
  qtypes_onehot = []
  ntypes = len(qt_dict)

  v0 = [0] * ntypes
  n = len(qtype_df)

  for qt in qtype_df:
    v = list(v0)
    qt_id = qt_dict[qt]
    v[qt_id] = 1
    # to be consistent with other seq data, put v in [] to increase 1 dimension
    qtypes_onehot.append([v])

  return qtypes_onehot

def list_matrices_to_list_question_types(qtypes_onehot):
  types = []
  for qt in qtypes_onehot:
    v = list(qt[0])
    tid = v.index(1)
    types.append( qt_reversed_dict[tid] )
  return types

# --------------------------------
# the following codes show how the original question_types_saved.pickle was created.
# the qtypes are saved in the beginning to create an common order for future reference

# file_qtypes_saved_before = os.path.join(data_main_path, "question_types_saved.pickle")
# qtypes = list(set(qa_df["question_type"]))
# qtypes.sort()
# qt_dict = {}
# for i in range(len(qtypes)):
#  qt_dict[ qtypes[i] ] = i

## save the dictionary for future lookup
# with open(file_qtypes_saved_before, 'wb') as f:
#  # store the qt_dict as binary data stream
#  pickle.dump(qt_dict, f)
# Out:
# number of unique question types = 65
# qtypes =  dict_keys(['are', 'are the', 'are there', 'are there any', 'are these', 'are they', 'can you', 'could', 'do', 'do you', 'does the', 'does this', 'has', 'how', 'how many', 'how many people are', 'how many people are in', 'is', 'is he', 'is it', 'is that a', 'is the', 'is the man', 'is the person', 'is the woman', 'is there', 'is there a', 'is this', 'is this a', 'is this an', 'is this person', 'none of the above', 'was', 'what', 'what animal is', 'what are', 'what are the', 'what brand', 'what color', 'what color are the', 'what color is', 'what color is the', 'what does the', 'what is', 'what is in the', 'what is on the', 'what is the', 'what is the color of the', 'what is the man', 'what is the name', 'what is the person', 'what is the woman', 'what is this', 'what kind of', 'what number is', 'what room is', 'what sport is', 'what time', 'what type of', 'where are the', 'where is the', 'which', 'who is', 'why', 'why is the'])
# qt_dict =  {'are': 0, 'are the': 1, 'are there': 2, 'are there any': 3, 'are these': 4, 'are they': 5, 'can you': 6, 'could': 7, 'do': 8, 'do you': 9, 'does the': 10, 'does this': 11, 'has': 12, 'how': 13, 'how many': 14, 'how many people are': 15, 'how many people are in': 16, 'is': 17, 'is he': 18, 'is it': 19, 'is that a': 20, 'is the': 21, 'is the man': 22, 'is the person': 23, 'is the woman': 24, 'is there': 25, 'is there a': 26, 'is this': 27, 'is this a': 28, 'is this an': 29, 'is this person': 30, 'none of the above': 31, 'was': 32, 'what': 33, 'what animal is': 34, 'what are': 35, 'what are the': 36, 'what brand': 37, 'what color': 38, 'what color are the': 39, 'what color is': 40, 'what color is the': 41, 'what does the': 42, 'what is': 43, 'what is in the': 44, 'what is on the': 45, 'what is the': 46, 'what is the color of the': 47, 'what is the man': 48, 'what is the name': 49, 'what is the person': 50, 'what is the woman': 51, 'what is this': 52, 'what kind of': 53, 'what number is': 54, 'what room is': 55, 'what sport is': 56, 'what time': 57, 'what type of': 58, 'where are the': 59, 'where is the': 60, 'which': 61, 'who is': 62, 'why': 63, 'why is the': 64}
# len(qtypes_cur) = 65

# %%
import os
import datetime

# The image feature data downloaded from https://github.com/MILVLG/mcan-vqa
data_path2 = os.path.join(main_path, "data/vqa_v2/MILVLG_mcan-vqa/")
#foldername = "image_features_examples_from_MILVLG_mcan-vqa"
foldername = "train2014"
filename = "{}.tar.gz".format(foldername)
tarfile =os.path.join(data_path2, filename)

image_path = os.path.join("./", foldername) # updated image path

# copy the tarfile to disk and extract it there
# !ls ./

# firstly, check if the extracted folder is there
if os.path.isdir(foldername):
  print ("folder {} exists. no need to copy and extract".format(foldername))
else:
  # if not then copy over, and later extract
  if os.path.isfile(filename):
    print ("file {} exists".format(filename))
  else:
    print ("start copying the file to home folder")
    print ("start time: ", datetime.datetime.now())
    # !cp "{tarfile}" .
    print ("end time: ", datetime.datetime.now())  

  # now extract the tar file
  print ("start extracting the tar file")
  print ("start time: ", datetime.datetime.now())
  # !tar xf "{filename}"
  print ("end time: ", datetime.datetime.now())

  if os.path.isdir(foldername):
    print ("extraction is done. remove tar file")
    # !rm "{filename}"
    
# !ls ./
# Out:
# gdrive	sample_data
# start copying the file to home folder
# start time:  2020-04-24 03:12:56.539571
# end time:  2020-04-24 03:21:08.947510
# start extracting the tar file
# start time:  2020-04-24 03:21:08.948089
# end time:  2020-04-24 03:26:08.598201
# extraction is done. remove tar file
# gdrive	sample_data  train2014

# %%
# !rm -r "train2014"

# %%
import os
import numpy as np

# sometimes the mounting will encounter the "Google Drive timeout" error. have to try for a few times
if not os.path.isdir(image_path):
  print("image features folder {} does not exist".format(image_path))
else:
  print ("image feature folder {} exists.".format(image_path))

# test
filename = "COCO_train2014_000000458752.jpg.npz"
filepath = os.path.join(image_path, filename)
if not os.path.isfile(filepath):
  print ("file {} does not exist".format(filepath))
else:
  print ("file {} can be found".format(filepath))

image = np.load(filepath)
print ("image.keys() = {}".format(image.keys()))
print ("image.files = {}".format(image.files))
print ("image['x'].shape = {}".format(image['x'].shape))
print ("image['image_w'] = {}".format(image['image_w']))
print ("image['image_h'] = {}".format(image['image_h']))
print ("image['num_bbox'] = {}".format(image['num_bbox']))
print ("image['bbox'].shape = {}".format(image['bbox'].shape))

# some stats computed offline:
# the maximum image features length is  99
# the 70.0 percentile image features length is 37
# the 80.0 percentile image features length is 41
# the 90.0 percentile image features length is 46
# the 95.0 percentile image features length is 51
# the 99.0 percentile image features length is 59
# the 99.9 percentile image features length is 69
# Out:
# image feature folder ./train2014 exists.
# file ./train2014/COCO_train2014_000000458752.jpg.npz can be found
# image.keys() = KeysView(<numpy.lib.npyio.NpzFile object at 0x7ffb00f87b70>)
# image.files = ['x', 'image_w', 'bbox', 'num_bbox', 'image_h']
# image['x'].shape = (2048, 34)
# image['image_w'] = 640
# image['image_h'] = 480
# image['num_bbox'] = 34
# image['bbox'].shape = (34, 4)

# %%
# print ("qa_df[\"image_id\"][0:100] = ", list(qa_df["image_id"][0:100]) )

# %%
## old codes

# get all the questions in one list
# questions_list = []
# for question in qlist:
#  questions_list.append(question['question'])
# tq.fit_on_texts(questions_list)

# tq = Tokenizer(num_words=1000, split=' ', char_level=False)
# tq.fit_on_texts(qa_df["question"])

# num_words_more_than_50_occurences = len( list( filter(lambda elem: elem[1] > 50, tq.word_counts.items()) ) )
# print ("num_words_more_than_50_occurences = {}".format(num_words_more_than_50_occurences))
# based on original questions in training data
# num_words_more_than_5_occurences = 6105
# num_words_more_than_10_occurences = 4495
# num_words_more_than_15_occurences = 3712
# num_words_more_than_20_occurences = 3194
# num_words_more_than_30_occurences = 2614
# num_words_more_than_50_occurences = 2039

# summary:
# print("tq.word_counts = {}".format(len(tq.word_counts)) )
# print("tq.document_count = {}".format(tq.document_count) )
# print("tq.word_index = {}".format(tq.word_index) )
# print("tq.word_docs = {}".format(tq.word_docs) )

# ta = Tokenizer(split=' ', char_level=False)
# ta.fit_on_texts(qa_df["answer"])
# print("ta.word_counts = {}".format(len(ta.word_counts)) )
# print("ta.document_count = {}".format(ta.document_count) )

# %%
# How the tokenizer is trained in the first place

# from keras.preprocessing.text import Tokenizer
# import pickle

# print ("qa_df.iloc[0] =\n{}".format(qa_df.iloc[0]))

# tqa = Tokenizer(num_words=MAX_NUM_WORDS, split=' ', char_level=False, oov_token=NULLTOKEN)
# tqa.fit_on_texts(qa_df["question"] + qa_df["answer"])
# print("tqa.word_counts = {}".format(len(tqa.word_counts)) )
# print("tqa.document_count = {}".format(tqa.document_count) )

# print ("tqa.word_index[\"the\"] = ", tqa.word_index["the"])

# print ("word index for the nulltoken = ", tqa.word_index[NULLTOKEN])

# save trained tokenizer to file
# filename = "tokenizer.pickle"
# filepath = os.path.join(output_path, filename)
# pickle.dump(tqa, open(filepath, 'wb'))
 

# The words kept by Tokenizer do not depend on freq.. just the most common words.
# Therefore the self-created SENTENCE_START and SENTENCE_END words are not there.

# sentence_start_index = tqa.word_index[SENTENCE_START]
# sentence_end_index = tqa.word_index[SENTENCE_END]
# print ("sentence_start_index = ", sentence_start_index)
# print ("sentence_end_index = ", sentence_end_index)

# %%
# load trained tokenizer from file
import pickle
import datetime

filename = "tokenizer.pickle"
filepath = os.path.join(output_path, filename)

print ("start time for loading tokenizer: ", datetime.datetime.now())
tqa = pickle.load(open(filepath, 'rb'))
print ("end time for loading tokenizer: ", datetime.datetime.now())

print("tqa.word_counts = {}".format(len(tqa.word_counts)) )
print("tqa.document_count = {}".format(tqa.document_count) )

print ("tqa.word_index[\"the\"] = ", tqa.word_index["the"])

# check what is the number for the nulltoken
NULLTOKEN_INDEX = tqa.word_index[NULLTOKEN]
print ("word index for the nulltoken = ", NULLTOKEN_INDEX)
# Out:
# start time for loading tokenizer:  2020-04-24 03:26:13.859463
# end time for loading tokenizer:  2020-04-24 03:26:19.068605
# tqa.word_counts = 19710
# tqa.document_count = 443757
# tqa.word_index["the"] =  2
# word index for the nulltoken =  1

# %%
import time
import numpy as np
import os
import random

# image features from https://github.com/MILVLG/mcan-vqa
# every image["x"] contains 2048 features for each bounding box;
# so the shape of image["x"] is always 2048*num_bbox

# image_path =  = os.path.join(data_main_path, "MILVLG_mcan-vqa")

def reduce_buffer_if_needed():
	n = len(image_data_buffer) 
	if n <= MAX_IMAGE_BUFFER_SIZE:
		print ("buffer ({}) not filled up.".format(n))
		return

	n_to_remove = n - MAX_IMAGE_BUFFER_SIZE
	print ("To remove {} items from buffer with size {}".format(n_to_remove, n))

	time_and_image_ids = []
	for key, item in image_data_buffer.items():
		time_and_image_ids.append((item["time"], key))

	# time_and_image_ids.sort() # deleted based on last accessed time
	random.shuffle(time_and_image_ids) # randomly delete

	for i in range(n_to_remove):
		print ("remove image (last accessed time, image id) = {}".format(time_and_image_ids[i]))
		del image_data_buffer[time_and_image_ids[i][1]]

	assert(n - n_to_remove == len(image_data_buffer))
	print ("After removing old items, len(image_data_buffer) = ", len(image_data_buffer))

def get_image_data_based_on_image_ids(list_image_ids):
	image_data = []
	list_found = []
	last_id = -1
	for image_id in list_image_ids:
		# print ("image_id = ", image_id)
		if image_id in image_data_buffer:
			image_data.append(image_data_buffer[image_id]["image"]["x"])
			list_found.append(True)
		else:
			image_id2 = str(image_id).zfill(12)
			filename = "COCO_train2014_{}.jpg.npz".format(image_id2)
			# print ("\nfile: {}".format(filename))

			filepath = os.path.join(image_path, filename)
   
			# for .npz file, a dictionary-like object is returned
			try:
				image = np.load(filepath)
			except:
				if image_id != last_id:
					print ("for image id {}, cannot find file {}. continue for testing".format(image_id, filepath))
				last_id = image_id
				list_found.append(False)
				continue

			image = dict(image)
			# print ("image.keys() = ", image.keys())
			# reshape x:
			image['x'] = image['x'].reshape((-1,2048))
			image_data_buffer[image_id] = {"image": image, "time": time.time()}
			image_data.append(image_data_buffer[image_id]["image"]["x"])
			list_found.append(True)

		# print ("image.keys() = {}".format(image.keys()))
		# print ("image['x'].shape = {}".format(image['x'].shape))

	print ("len(list_found) = {}, len(list_image_ids) = {}".format(len(list_found), len(list_image_ids)))
	assert(len(list_found) == len(list_image_ids))
	assert(sum(list_found) == len(image_data)) 
	reduce_buffer_if_needed()

	return image_data, list_found

# test
list_image_ids = qa_df["image_id"][0:100]
image_data, list_found = get_image_data_based_on_image_ids(list_image_ids)
print ("len(list_image_ids) = {}, len(image_data) = {}".format(len(list_image_ids), len(image_data)))
if len(image_data) > 0:
  print ("image_data[0].shape = ", image_data[0].shape)
# assert(len(list_image_ids) == len(image_data))
# Out:
# len(list_found) = 100, len(list_image_ids) = 100
# buffer (17) not filled up.
# len(list_image_ids) = 100, len(image_data) = 100
# image_data[0].shape =  (34, 2048)

# %%
from keras.preprocessing import sequence
import numpy as np

def list_texts_to_encoded_sequence(df, tokenizer):
  # list_texts = [ x.split() for x in df ]
  # convert a list of strings to a list of sequences (one sequence is a list of integers)
  # the words that are dropped by the Tokenizer will be dropped too..
  seqs = tokenizer.texts_to_sequences(df)
  # encoded = tokenizer_model.sequences_to_matrix(encoded) 
  return seqs

def one_seq_to_one_matrix(s):
	n = len(s)
	matrix = []
	v0 = [0] * MAX_NUM_WORDS
	for i in range(n):
		v = list(v0)
		v[s[i]] = 1
		matrix.append(v)
	return matrix

def sequences_to_list_onehot_matrices(seqs):
	lmatrices = []
	for s in seqs:
		lmatrices.append(one_seq_to_one_matrix(s))
	return lmatrices

def list_texts_to_list_onehot_matrices(df, tokenizer):
  return sequences_to_list_onehot_matrices(list_texts_to_encoded_sequence(df, tokenizer))

# converting a list of matrices back to a list of texts
def list_matrices_to_list_seqs(lmatrices):
  ls = []
  for m in lmatrices:
    s = []
    for row in m:
      row = list(row)
      index = row.index(max(row))
      s.append(index)
    ls.append(s)
  return ls


def list_matrices_to_list_texts(lmatrices):
  return tqa.sequences_to_texts(list_matrices_to_list_seqs(lmatrices))


def list_sequences_to_texts(lseq):
  return tqa.sequences_to_texts(lseq)
# Out:
# Using TensorFlow backend.

# %%
def format_answer_texts(adf):
  adata = list_texts_to_list_onehot_matrices(adf, tqa)

  adata = sequence.pad_sequences(adata, maxlen=MAX_ANSWER_LENGTH, padding='post', truncating='post')
  # adata = np.expand_dims(adata, axis=3) 
  print ("adata.shape = {}".format(adata.shape))
  return adata

# return associated questions and answers
def get_train_data_qa(start, end):
  qdf = qa_df["question"][start:end]

  qdata = list_texts_to_list_onehot_matrices(qdf, tqa)

  qdata = sequence.pad_sequences(qdata, maxlen=MAX_QUESTION_LENGTH, padding='post', truncating='post')
  # qdata = np.expand_dims(qdata, axis=3)
  print ("qdata.shape = {}".format(qdata.shape))

  adf = qa_df["answer"][start:end]
  adata = format_answer_texts(adf)

  #adata = list_texts_to_list_onehot_matrices(adf, tqa)

  #adata = sequence.pad_sequences(adata, maxlen=MAX_ANSWER_LENGTH, padding='post', truncating='post')
  # adata = np.expand_dims(adata, axis=3) 
  #print ("adata.shape = {}".format(adata.shape))

  return qdata, adata

# return associated questions, answers, media, and question types
def get_train_data(start, end):
  qdf = qa_df["question"][start:end]

  qdata = list_texts_to_list_onehot_matrices(qdf, tqa)

  qdata = sequence.pad_sequences(qdata, maxlen=MAX_QUESTION_LENGTH, padding='post', truncating='post')
  # qdata = np.expand_dims(qdata, axis=3)
  print ("qdata.shape = {}".format(qdata.shape))

  adf = qa_df["answer"][start:end]
  adata = list_texts_to_list_onehot_matrices(adf, tqa)

  adata = sequence.pad_sequences(adata, maxlen=MAX_ANSWER_LENGTH, padding='post', truncating='post')
  # adata = np.expand_dims(adata, axis=3) 
  print ("adata.shape = {}".format(adata.shape))

  qtype_df = qa_df["question_type"][start:end]
  qtype_data = get_one_hot_representation_qtype(qtype_df)
  qtype_data = sequence.pad_sequences(qtype_data, maxlen=MAX_QUESTION_TYPE_LENGTH, padding='post', truncating='post')
  print ("qtype_data.shape = {}".format(qtype_data.shape))

  image_ids = qa_df["image_id"][start:end]
  image_data, list_found = get_image_data_based_on_image_ids(image_ids)
  image_data = sequence.pad_sequences(image_data, maxlen=MEDIA_MAX_LENGTH, padding='post', truncating='post')
  print ("image_data.shape = {}".format(image_data.shape))
  qdata = qdata[list_found]
  adata = adata[list_found]
  qtype_data = qtype_data[list_found]

  print ("qdata.shape = {}".format(qdata.shape))
  print ("adata.shape = {}".format(adata.shape))
  print ("qtype_data.shape = {}".format(qtype_data.shape))

  return {'question_data': qdata,
          'answer_data': adata,
          'media_data': image_data,
          'questionType_data': qtype_data,
          'question_texts': qdf,
          'answer_texts': adf,
          'questionType_texts': qtype_df,
          'media_ids': image_ids,
          'question_seqs': list_texts_to_encoded_sequence(qdf, tqa),
          'answer_seqs': list_texts_to_encoded_sequence(adf, tqa)}

def get_train_data_qam(start, end):
  data = get_train_data(start, end)
  # return qdata, adata, image_data
  return data['question_data'], data['answer_data'], data['media_data']

# test
print ("\ntest get_train_data_qa")
qdata, adata = get_train_data_qa(0, 100)

print ("\ntest get_train_data")
data = get_train_data(0, 99)

print ("\ntest get_train_data_qam")
qdata, adata, image_data = get_train_data_qam(0, 100)
# Out:
# test get_train_data_qa
# qdata.shape = (100, 25, 3200)
# adata.shape = (100, 10, 3200)
#
# test get_train_data
# qdata.shape = (99, 25, 3200)
# adata.shape = (99, 10, 3200)
# qtype_data.shape = (99, 1, 65)
# len(list_found) = 99, len(list_image_ids) = 99
# buffer (17) not filled up.
# image_data.shape = (99, 70, 2048)
# qdata.shape = (99, 25, 3200)
# adata.shape = (99, 10, 3200)
# qtype_data.shape = (99, 1, 65)
#
# test get_train_data_qam
# qdata.shape = (100, 25, 3200)
# adata.shape = (100, 10, 3200)
# qtype_data.shape = (100, 1, 65)
# len(list_found) = 100, len(list_image_ids) = 100
# buffer (17) not filled up.
# image_data.shape = (100, 70, 2048)
# qdata.shape = (100, 25, 3200)
# adata.shape = (100, 10, 3200)
# qtype_data.shape = (100, 1, 65)

# %%
# seq2seq with 2 inputs. one is text, the other is a list of representation from an image/vidoe. 
# reference: https://medium.com/softmax/multi-input-seq2seq-generation-with-keras-and-talos-84d8bdec2d46

# when this is used for question+image -> answer, the 1st input is the question, and the 2nd input is the image.
# note that the image is trained offline. The input here is just a list of vectors, each of which could be a flattened vector of a m*m*c region.

from keras.layers import Dense, TimeDistributed, CuDNNLSTM, LSTM, RepeatVector, Input, concatenate, Flatten
from keras.models import Model
from keras.optimizers import Adam

# The simplest model that can take 2 seq as input and produce 1 seq as output;
# There is slightly improved model in the next cell
def set_up_simple_model(params):
    print("parameters:", params)
    # colab sometimes limits usage of GPU; to be safe, train using the normal CPU so the saved model can be used
    if params["GPU"] == True:
      LSTM__ = CuDNNLSTM
    else:
      LSTM__ = LSTM
      print ("Use normal LSTM")

    optim = Adam(lr=params["lr"])

    # text input seq
    text_input = Input(shape = params["text_shape"], name='text')

    # media input seq
    media_input = Input(shape = params["media_shape"], name='media')

    # text input goes into one LSTM
    lstm_text_repr = LSTM__(params["layer_1_text_input_neuron"])(text_input)

    # media input goes into another LSTM
    lstm_media_repr = LSTM__(params["layer_1_media_input_neuron"])(media_input)

    # concatenate the 2 outputs from the LSTM cells
    concatenated = concatenate([lstm_text_repr, lstm_media_repr], axis=-1)

    # repeat the concatenated represention for OUTPUT_SEQ_LENGTH
    concatenated_repeated = RepeatVector(params["output_shape1"])(concatenated)

    # feed the seq into another LSTM, which will lead to OUTPUT_SEQ_LENGTH steps
    concatenated_lstm = LSTM__(params["concatenated_layer_neuron"], return_sequences=True)(concatenated_repeated)

    # apply a Dense on each step's output from the last LSTM
    timedistributed = TimeDistributed(Dense(params["output_shape2"], activation='softmax'))(concatenated_lstm)

    model = Model([text_input, media_input], timedistributed)
    model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['acc'])
    return model

# test
params={
    "GPU": False, # if False, CPU will be used; to use GPU instead, set it to True and also configure Runtime -> change runtime type
    "lr":0.001,
    "text_shape":(MAX_QUESTION_LENGTH, MAX_NUM_WORDS),
    "media_shape":(MEDIA_MAX_LENGTH, MEDIA_FEATURE_DIMENSION),
    "output_shape1": MAX_ANSWER_LENGTH, # output length
    "output_shape2": MAX_NUM_WORDS, # number of possible words
    "layer_1_text_input_neuron": 100,
    "layer_1_media_input_neuron": 150,
    "concatenated_layer_neuron": 200,
}


model_ag_test = set_up_simple_model(params)
print(model_ag_test.summary())
# Out:
# parameters: {'GPU': False, 'lr': 0.001, 'text_shape': (25, 3200), 'media_shape': (70, 2048), 'output_shape1': 10, 'output_shape2': 3200, 'layer_1_text_input_neuron': 100, 'layer_1_media_input_neuron': 150, 'concatenated_layer_neuron': 200}
# Use normal LSTM
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               (None, 25, 3200)     0
# __________________________________________________________________________________________________
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 250)          0           lstm_1[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 10, 250)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 10, 200)      360800      repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 10, 3200)     643200      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,643,800
# Trainable params: 3,643,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# seq2seq with 2 inputs. one is text, the other is a list of representation from an image/vidoe. 

from keras.layers import Dense, TimeDistributed, CuDNNLSTM, LSTM, RepeatVector, Input, concatenate, Flatten
from keras.models import Model
from keras.optimizers import Adam

# Improve the the simple model by adding a condensed repr of media to the last lstm
def set_up_model2(params):
    print("parameters:", params)
    # colab sometimes limits usage of GPU; to be safe, train using the normal CPU so the saved model can be used
    if params["GPU"] == True:
      LSTM__ = CuDNNLSTM
    else:
      LSTM__ = LSTM
      print ("Use normal LSTM")

    optim = Adam(lr=params["lr"])

    # text input seq
    text_input = Input(shape = params["text_shape"], name='text')

    # media input seq
    media_input = Input(shape = params["media_shape"], name='media')

    # text input goes into one LSTM
    lstm_text_repr = LSTM__(params["layer_1_text_input_neuron"])(text_input)

    # media input goes into another LSTM
    lstm_media_repr = LSTM__(params["layer_1_media_input_neuron"])(media_input)

    # one more smaller lstm to get the return seq for each component in the media
    condensed_media = LSTM__(20, return_sequences=True)(media_input)

    # flatten it to 1d dim
    condensed_media = Flatten()(condensed_media)

    # concatenate the 2 outputs from the LSTM cells
    # compared to the simple model, the condensed version of media is also an input to every single step of the last LSTM
    concatenated = concatenate([lstm_text_repr, lstm_media_repr, condensed_media], axis=-1)

    # repeat the concatenated represention for OUTPUT_SEQ_LENGTH
    concatenated_repeated = RepeatVector(params["output_shape1"])(concatenated)

    # feed the seq into another LSTM, which will lead to OUTPUT_SEQ_LENGTH steps
    concatenated_lstm = LSTM__(params["concatenated_layer_neuron"], return_sequences=True)(concatenated_repeated)

    # apply a Dense on each step's output from the last LSTM
    timedistributed = TimeDistributed(Dense(params["output_shape2"], activation='softmax'))(concatenated_lstm)

    model = Model([text_input, media_input], timedistributed)
    model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['acc'])
    return model
    


# test
params={
    "GPU": False, # if False, CPU will be used; to use GPU instead, set it to True and also configure Runtime -> change runtime type
    "lr":0.001,
    "text_shape":(MAX_QUESTION_LENGTH, MAX_NUM_WORDS),
    "media_shape":(MEDIA_MAX_LENGTH, MEDIA_FEATURE_DIMENSION),
    "output_shape1": MAX_ANSWER_LENGTH, # output length
    "output_shape2": MAX_NUM_WORDS, # number of possible words
    "layer_1_text_input_neuron": 100,
    "layer_1_media_input_neuron": 150,
    "concatenated_layer_neuron": 200,
}


model_ag_test = set_up_model2(params)
print(model_ag_test.summary())
# Out:
# parameters: {'GPU': False, 'lr': 0.001, 'text_shape': (25, 3200), 'media_shape': (70, 2048), 'output_shape1': 10, 'output_shape2': 3200, 'layer_1_text_input_neuron': 100, 'layer_1_media_input_neuron': 150, 'concatenated_layer_neuron': 200}
# Use normal LSTM
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 25, 3200)     0
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 70, 20)       165520      media[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1400)         0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1650)         0           lstm_4[0][0]
#                                                                  lstm_5[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 10, 1650)     0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 10, 200)      1480800     repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 10, 3200)     643200      lstm_7[0][0]
# ==================================================================================================
# Total params: 4,929,320
# Trainable params: 4,929,320
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# choose the type of model
# set_up_model = set_up_simple_model
set_up_model = set_up_model2

# %%
# construct answer generator model with QUESTION TEXT as input

# Using VQA V2 existing features (downloaded from https://github.com/MILVLG/mcan-vqa)

from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.models import load_model
import pandas as pd
import os

# Note that the inputs are question and media, and output is answer
params={
    "GPU": False, # if False, CPU will be used; to use GPU instead, set it to True and also configure Runtime -> change runtime type
    "lr":0.001,
    "text_shape":(MAX_QUESTION_LENGTH, MAX_NUM_WORDS),
    "media_shape":(MEDIA_MAX_LENGTH, MEDIA_FEATURE_DIMENSION),
    "output_shape1": MAX_ANSWER_LENGTH, # output length
    "output_shape2": MAX_NUM_WORDS, # number of possible words
    "layer_1_text_input_neuron": 100,
    "layer_1_media_input_neuron": 150,
    "concatenated_layer_neuron": 200,
}

# get data and train

file_saved_model = os.path.join(output_path, "ag_question_as_input_100_150_200_cpu.model2")
if os.path.isfile(file_saved_model):
  model_ag1 = load_model(file_saved_model) # continue from last checkpoint
  print("load existing model from ", file_saved_model)
else:
  print ("Existing model is not found. Start with a new model.")
  model_ag1 = set_up_model(params)

print(model_ag1.summary())

# save every n epoches
checkpoint = ModelCheckpoint(file_saved_model, monitor='acc', verbose=1, save_best_only=False, mode='max', period=10)

ndata = len(qa_df)

# size = 500 # for testing
size = 2000
start = 157*size

n_rounds_for_1_pass = int(ndata/size) + 1
print ("n_rounds_for_1_pass = ", n_rounds_for_1_pass)

# fetch data section by section so that it won't use up all the ram
for i in range( n_rounds_for_1_pass * 300 ):
  print ("running round ", i)

  # make sure validation data is the same after 1 pass of the whole data
  if start >= ndata:
    start = 0
  print ("start: {} (total data = {})".format(start, ndata))

  qdata, adata, media_data = get_train_data_qam(start, start+size)
  start = start + size

  if (len(qdata) != len(media_data)) or len(qdata) == 0:
    print( "len(qdata) ({}) != len(media_data) ({}). likely the part to get images has some temporary mounting issues. skip this section of data.".format( len(qdata), len(media_data) ) )
    continue

  # qdata_media = pd.DataFrame.from_dict( {"question": qdata, "media": media_data} ) # need to merge qdata and media in order to do the split
  # X_train, X_test, y_train, y_test = train_test_split(
  #    qdata_media, adata, test_size=0.2, random_state=50)

  # A simple split of data to training and testing data
  train_size = int(0.8 * len(qdata))
  qdata_train = qdata[0:train_size]
  qdata_test = qdata[train_size:]
  adata_train = adata[0:train_size]
  adata_test = adata[train_size:]
  media_data_train = media_data[0:train_size]
  media_data_test = media_data[train_size:]

  print ("qdata_train.shape = ", qdata_train.shape)
  print ("qdata_test.shape = ", qdata_test.shape)
  print ("adata_train.shape = ", adata_train.shape)
  print ("adata_test.shape = ", adata_test.shape)
  print ("media_data_train.shape = ", media_data_train.shape)
  print ("media_data_test.shape = ", media_data_test.shape)

  if i % 10 == 0 and os.path.isfile(file_saved_model):
    # reload the model from file once in a while, in case the .fit() function buffers too much data
    model_ag1 = None
    model_ag1 = load_model(file_saved_model)
    print ("reload model from file")

  out=model_ag1.fit({'text': qdata_train, 'media': media_data_train}, 
                adata_train, 
                epochs=20,
                batch_size=20, 
                validation_data=({'text': qdata_test, 'media': media_data_test}, adata_test), 
                verbose=1,
                callbacks=[checkpoint])
# Out:
# load existing model from  /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_question_as_input_100_150_200_cpu.model2
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 25, 3200)     0
# __________________________________________________________________________________________________
# lstm_40 (LSTM)                  (None, 70, 20)       165520      media[0][0]
# __________________________________________________________________________________________________
# lstm_38 (LSTM)                  (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_39 (LSTM)                  (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1400)         0           lstm_40[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1650)         0           lstm_38[0][0]
#                                                                  lstm_39[0][0]
#                                                                  flatten_8[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 10, 1650)     0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_41 (LSTM)                  (None, 10, 200)      1480800     repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 10, 3200)     643200      lstm_41[0][0]
# ==================================================================================================
# Total params: 4,929,320
# Trainable params: 4,929,320
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# n_rounds_for_1_pass =  222
# running round  0
# start: 314000 (total data = 443757)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# len(list_found) = 2000, len(list_image_ids) = 2000
# buffer (362) not filled up.
# image_data.shape = (2000, 70, 2048)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# qdata_train.shape =  (1600, 25, 3200)
# qdata_test.shape =  (400, 25, 3200)
# adata_train.shape =  (1600, 10, 3200)
# adata_test.shape =  (400, 10, 3200)
# media_data_train.shape =  (1600, 70, 2048)
# media_data_test.shape =  (400, 70, 2048)
# reload model from file
# Train on 1600 samples, validate on 400 samples
# Epoch 1/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.4054 - acc: 0.0255 - val_loss: 0.5574 - val_acc: 0.0235
# Epoch 2/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.3621 - acc: 0.0265 - val_loss: 0.5589 - val_acc: 0.0247
# Epoch 3/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.3474 - acc: 0.0273 - val_loss: 0.5502 - val_acc: 0.0260
# Epoch 4/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.3326 - acc: 0.0301 - val_loss: 0.5645 - val_acc: 0.0253
# Epoch 5/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.
20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.1206 - acc: 0.0890 - val_loss: 0.5866 - val_acc: 0.0223
#
# Epoch 00010: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_question_as_input_100_150_200_cpu.model2
# Epoch 11/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.0994 - acc: 0.0928 - val_loss: 0.5904 - val_acc: 0.0220
# Epoch 12/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0839 - acc: 0.0962 - val_loss: 0.5984 - val_acc: 0.0225
# Epoch 13/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0679 - acc: 0.1008 - val_loss: 0.6218 - val_acc: 0.0230
# Epoch 14/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0599 - acc: 0.1016 - val_loss: 0.6231 - val_acc: 0.0227
# Epoch 15/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.0513 - acc: 0.1043 - val_loss: 0.6288 - val_acc: 0.0233
# Epoch 16/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.0437 - acc: 0.1067 - val_loss: 0.6416 - val_acc: 0.0235
# Epoch 17/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.0380 - acc: 0.1079 - val_loss: 0.6391 - val_acc: 0.0233
# Epoch 18/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.0353 - acc: 0.1081 - val_loss: 0.6448 - val_acc: 0.0217
# Epoch 19/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0334 - acc: 0.1083 - val_loss: 0.6593 - val_acc: 0.0217
# Epoch 20/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.0299 - acc: 0.1092 - val_loss: 0.6596 - val_acc: 0.0230
#
# Epoch 00020: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_question_as_input_100_150_200_cpu.model2
# running round  36
# start: 386000 (total data = 443757)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# len(list_found) = 2000, len(list_image_ids) = 2000
# buffer (13882) not filled up.
# image_data.shape = (2000, 70, 2048)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# qdata_train.shape =  (1600, 25, 3200)
# qdata_test.shape =  (400, 25, 3200)
# adata_train.shape =  (1600, 10, 3200)
# adata_test.shape =  (400, 10, 3200)
# media_data_train.shape =  (1600, 70, 2048)
# media_data_test.shape =  (400, 70, 2048)
# Train on 1600 samples, validate on 400 samples
# Epoch 1/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.5346 - acc: 0.0274 - val_loss: 0.3902 - val_acc: 0.0290
# Epoch 2/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.4082 - acc: 0.0355 - val_loss: 0.3874 - val_acc: 0.0278
# Epoch 3/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.3643 - acc: 0.0432 - val_loss: 0.3974 - val_acc: 0.0278
# Epoch 4/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.3202 - acc: 0.0486 - val_loss: 0.4039 - val_acc: 0.0268
# Epoch 5/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.2803 - acc: 0.0548 - val_loss: 0.4175 - val_acc: 0.0280
# Epoch 6/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.2423 - acc: 0.0617 - val_loss: 0.4241 - val_acc: 0.0250
# Epoch 7/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.2039 - acc: 0.0677 - val_loss: 0.4474 - val_acc: 0.0237
# Epoch 8/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.1712 - acc: 0.0761 - val_loss: 0.4564 - val_acc: 0.0240
# Epoch 9/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.1429 - acc: 0.0801 - val_loss: 0.4672 - val_acc: 0.0240
# Epoch 10/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.1163 - acc: 0.0853 - val_loss: 0.4852 - val_acc: 0.0245
#
# Epoch 00010: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_question_as_input_100_150_200_cpu.model2
# Epoch 11/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0951 - acc: 0.0909 - val_loss: 0.4922 - val_acc: 0.0237
# Epoch 12/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.0789 - acc: 0.0939 - val_loss: 0.5146 - val_acc: 0.0243
# Epoch 13/20
#  400/1600 [======>.......................] - ETA: 21s - loss: 0.0569 - acc: 0.1047Buffered data was truncated after reaching the output size limit.

# %%
# test the AG model with question text as input
# load the trained model and test

from keras.models import load_model

filename = "ag_question_as_input_100_150_200_cpu.model2"
file_saved_model = os.path.join(output_path, filename)
model_ag1_trained = load_model(file_saved_model)
print(model_ag1_trained.summary())

# get some data and make prediction
qdata, adata, media_data = get_train_data_qam(0, 30)
answers_predicted = model_ag1_trained.predict({'text': qdata, 'media': media_data})

print ("answers_predicted.shape = ", answers_predicted.shape)
print ("type(answers_predicted) = ", type(answers_predicted))

print ("answers_predicted[0, :] = ", answers_predicted[0, :])

answer_text = list_matrices_to_list_texts(answers_predicted)
qdata_text = list_matrices_to_list_texts(qdata)
adata_text = list_matrices_to_list_texts(adata)
for i in range(len(qdata)):
  print("\nquestion: ", qdata_text[i])
  print("given answer: ", adata_text[i])
  print ("predicted answer sequence = ", answer_text[i])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 25, 3200)     0
# __________________________________________________________________________________________________
# lstm_40 (LSTM)                  (None, 70, 20)       165520      media[0][0]
# __________________________________________________________________________________________________
# lstm_38 (LSTM)                  (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_39 (LSTM)                  (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1400)         0           lstm_40[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1650)         0           lstm_38[0][0]
#                                                                  lstm_39[0][0]
#                                                                  flatten_8[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 10, 1650)     0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_41 (LSTM)                  (None, 10, 200)      1480800     repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 10, 3200)     643200      lstm_41[0][0]
# ==================================================================================================
# Total params: 4,929,320
# Trainable params: 4,929,320
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# len(list_found) = 30, len(list_image_ids) = 30
# buffer (17) not filled up.
# image_data.shape = (30, 70, 2048)
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# answers_predicted.shape =  (30, 10, 3200)
# type(answers_predicted) =  <class 'numpy.ndarray'>
# answers_predicted[0, :] =  [[2.7851184e-08 7.1172235e-03 1.3281426e-08 ... 1.5506266e-06
#   5.9715139e-09 2.7716158e-08]
#  [9.0690451e-09 1.9401232e-04 1.2317707e-09 ... 8.8688381e-08
#   1.9581050e-08 9.2928989e-09]
#  [2.0013675e-09 2.9340465e-04 3.4200201e-10 ... 1.4713723e-07
#   4.5288746e-09 2.0261874e-09]
#  ...
#  [3.8060990e-09 2.3668844e-04 1.2406370e-10 ... 8.5015749e-08
#   8.5719432e-09 3.8693124e-09]
#  [3.9072221e-09 2.3333283e-04 1.1958744e-10 ... 8.4227757e-08
#   8.8565342e-09 3.9735695e-09]
#  [3.9101771e-09 2.2996713e-04 1.1449536e-10 ... 8.5123837e-08
#   8.7322807e-09 3.9780006e-09]]
#
# question:  what is this photo taken looking through NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  net NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  flowers dog dog dog dog dog dog dog dog dog
#
# question:  what position is this man playing NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  pitcher NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  NULLTOKEN and cheese NULLTOKEN cheese NULLTOKEN cheese horse NULLTOKEN horse
#
# question:  what color is the players shirt NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  orange NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  red and white and white and green and green and
#
# question:  is this man a professional baseball player NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes yes yes yes yes yes yes yes yes
#
# question:  what color is the snow NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  white NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  white white white and blue and blue blue blue blue
#
# question:  what is the person doing NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  skiing NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  flying 19 walking keep walking crossing crossing hands hands hands
#
# question:  what color is the persons NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  red NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  sunny and white white white white white white white white
#
# question:  what is in the person's hand NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  frisbee NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  fence show teeth teeth teeth teeth teeth teeth teeth teeth
#
# question:  is the dog waiting NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes yes yes yes yes yes yes NULLTOKEN yes
#
# question:  is the dog looking at a tennis ball or frisbee NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  frisbee NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  is the sky blue NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes yes yes yes yes yes yes yes yes
#
# question:  is there snow on the mountains NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes yes yes yes yes yes yes yes yes
#
# question:  what is the white NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  NULLTOKEN cup NULLTOKEN cup cup cup cup cup cup cup
#
# question:  is the window open NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes no no no no no no no no no
#
# question:  what color is the toothbrush NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  white and purple NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  brown and orange and white white white white white white
#
# question:  what is the child doing NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  brushing teeth NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  NULLTOKEN and NULLTOKEN and and and and and and and
#
# question:  is she brushing NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes no no no no no no no no
#
# question:  is the man smiling NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  what is the business man doing in the picture NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  flying it up up off off off off off off
#
# question:  does his tie pair well with his suit NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes yes yes yes yes yes yes yes yes yes
#
# question:  does the man look happy NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  is this photo in color NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  is the man wearing a plain tie NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  judging from the dress was this taken in a NULLTOKEN american country NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  what colors are shown in this picture NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  black and white NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  red and white and yellow and yellow and yellow and
#
# question:  are the men on the sidewalk NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes no no no no no no no no no
#
# question:  was this photo taken recently NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  no NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  yes no no no no no no no no no
#
# question:  does the guy have a tattoo NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  yes NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  no no no no no no no no no no
#
# question:  what is this man riding on NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  skateboard NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  street remote remote drive remote drive drive drive drive drive
#
# question:  how many tattoos can be seen on this man's body NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given answer:  1 NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# predicted_answer =  1 bears bears air st st st st st st

# %%
# construct answer generator model with QUESTION TYPE as input
# (VQA V2 dataset provides question type, which saves our works to get the types from question texts)

# Using VQA V2 existing features (downloaded from https://github.com/MILVLG/mcan-vqa)

# Note that the inputs are question types and media, and output is answer
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.models import load_model
import pandas as pd
import os

params={
    "GPU": False, # if False, CPU will be used; to use GPU instead, set it to True and also configure Runtime -> change runtime type
    "lr":0.001,
    "text_shape":(MAX_QUESTION_TYPE_LENGTH, QUESTION_TYPE_DIMENSION),
    "media_shape":(MEDIA_MAX_LENGTH, MEDIA_FEATURE_DIMENSION),
    "output_shape1": MAX_ANSWER_LENGTH, # output length
    "output_shape2": MAX_NUM_WORDS, # number of possible words
    "layer_1_text_input_neuron": 100,
    "layer_1_media_input_neuron": 150,
    "concatenated_layer_neuron": 200,
}

# get data and train

file_saved_model = os.path.join(output_path, "ag_questionTypes_as_input_100_150_200_cpu.model2")
if os.path.isfile(file_saved_model):
  print ("load model from file")
  model_ag2 = load_model(file_saved_model) # continue from last checkpoint
else:
  model_ag2 = set_up_model(params)

print(model_ag2.summary())

# save every n epoches
checkpoint = ModelCheckpoint(file_saved_model, monitor='acc', verbose=1, save_best_only=False, mode='max', period=10)

ndata = len(qa_df)
# start = 0
# size = 500 # for testing
size = 2000
start = 0*size
n_rounds_for_1_pass = int(ndata/size) + 1
print ("n_rounds_for_1_pass = ", n_rounds_for_1_pass)

# fetch data section by section so that it won't use up all the ram
for i in range( n_rounds_for_1_pass * 300 ):
  print ("running round ", i)

  # make sure validation data is the same after 1 pass of the whole data
  if start >= ndata:
    start = 0
  print ("start: {} (total data = {})".format(start, ndata))

  data = get_train_data(start, start+size)
  qdata = data["questionType_data"]
  adata = data["answer_data"]
  media_data = data["media_data"]

  start = start + size

  if (len(qdata) != len(media_data)) or len(qdata) == 0:
    print( "len(qdata) ({}) != len(media_data) ({}). likely the part to get images has some temporary mounting issues. skip this section of data.".format( len(qdata), len(media_data) ) )
    continue

  train_size = int(0.8 * len(qdata))
  qdata_train = qdata[0:train_size]
  qdata_test = qdata[train_size:]
  adata_train = adata[0:train_size]
  adata_test = adata[train_size:]
  media_data_train = media_data[0:train_size]
  media_data_test = media_data[train_size:]

  print ("qdata_train.shape = ", qdata_train.shape)
  print ("qdata_test.shape = ", qdata_test.shape)
  print ("adata_train.shape = ", adata_train.shape)
  print ("adata_test.shape = ", adata_test.shape)
  print ("media_data_train.shape = ", media_data_train.shape)
  print ("media_data_test.shape = ", media_data_test.shape)

  if i % 10 == 0 and os.path.isfile(file_saved_model):
    # reload the model from file once in a while, in case the .fit() function buffers too much data
    model_ag2 = None
    model_ag2 = load_model(file_saved_model)
    print ("reload model from file")

  out=model_ag2.fit({'text': qdata_train, 'media': media_data_train}, 
                adata_train, 
                epochs=20,
                batch_size=20, 
                validation_data=({'text': qdata_test, 'media': media_data_test}, adata_test), 
                verbose=1,
                callbacks=[checkpoint])
# Out:
# parameters: {'GPU': False, 'lr': 0.001, 'text_shape': (1, 65), 'media_shape': (70, 2048), 'output_shape1': 10, 'output_shape2': 3200, 'layer_1_text_input_neuron': 100, 'layer_1_media_input_neuron': 150, 'concatenated_layer_neuron': 200}
# Use normal LSTM
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 1, 65)        0
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  (None, 70, 20)       165520      media[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 100)          66400       text[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1400)         0           lstm_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1650)         0           lstm_8[0][0]
#                                                                  lstm_9[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_3 (RepeatVector)  (None, 10, 1650)     0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  (None, 10, 200)      1480800     repeat_vector_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 10, 3200)     643200      lstm_11[0][0]
# ==================================================================================================
# Total params: 3,675,320
# Trainable params: 3,675,320
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# n_rounds_for_1_pass =  222
# running round  0
# start: 0 (total data = 443757)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# len(list_found) = 2000, len(list_image_ids) = 2000
# buffer (385) not filled up.
# image_data.shape = (2000, 70, 2048)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# qdata_train.shape =  (1600, 1, 65)
# qdata_test.shape =  (400, 1, 65)
# adata_train.shape =  (1600, 10, 3200)
# adata_test.shape =  (400, 10, 3200)
# media_data_train.shape =  (1600, 70, 2048)
# media_data_test.shape =  (400, 70, 2048)
# Train on 1600 samples, validate on 400 samples
# Epoch 1/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.6165 - acc: 0.0191 - val_loss: 0.5757 - val_acc: 0.0190
# Epoch 2/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.4921 - acc: 0.0205 - val_loss: 0.5823 - val_acc: 0.0158
# Epoch 3/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.4822 - acc: 0.0207 - val_loss: 0.5879 - val_acc: 0.0158
# Epoch 4/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.4778 - acc: 0.0204 - val_loss: 0.5893 - val_acc: 0.0190
# Epoch 5/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.4720 - acc: 0.0200 - val_loss: 0.5783 - val_acc: 0.0227
# Epoch 6/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.4516 - acc: 0.0203 - val_loss: 0.5577 - val_acc: 0.0178
# Epoch 7/20
# 1600/1600 [==============================] - 33s 20ms/step - loss: 0.4293 - acc: 0.0221 - val_loss: 0.5472 - val_acc: 0.0255
# Epoch 8/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.4136 - acc: 0.0255 - val_loss: 0.5384 - val_acc: 0.0240
# Epoch 9/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.4030 - acc: 0.0243 - val_loss: 0.5399 - val_acc: 0.0230
# Epoch 10/20
# 1600/1600 [==============================] - 29s 18ms/step - loss: 0.3941 - acc: 0.0248 - val_loss: 0.5393 - val_acc: 0.0270
#
# Epoch 00010: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_questionTypes_as_input_100_150_200_cpu.model2
# Epoch 11/20
# 1600/1600 [==============================] - 31s 20ms/step - loss: 0.3841 - acc: 0.0266 - val_loss: 0.5305 - val_acc: 0.0290
# Epoch 12/20
# 1600/1600 [==============================] - 33s 21ms/step - loss: 0.3752 - acc: 0.0277 - val_loss: 0.5323 - val_acc: 0.0260
# Epoch 13/20
# 1600/1600 [==============================] - 32s 20ms/step - loss: 0.3662 - acc: 0.0294 - val_loss: 0.5334 - val_acc: 0.0280
# Epoch 14/20
# 1600/1600 [==============================] - 31s 19ms/step - loss: 0.
20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.4179 - acc: 0.0336 - val_loss: 0.5460 - val_acc: 0.0200
# Epoch 3/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.3661 - acc: 0.0408 - val_loss: 0.5549 - val_acc: 0.0195
# Epoch 4/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.3286 - acc: 0.0454 - val_loss: 0.5594 - val_acc: 0.0200
# Epoch 5/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.2935 - acc: 0.0512 - val_loss: 0.5873 - val_acc: 0.0175
# Epoch 6/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.2606 - acc: 0.0557 - val_loss: 0.5931 - val_acc: 0.0185
# Epoch 7/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.2316 - acc: 0.0601 - val_loss: 0.5966 - val_acc: 0.0178
# Epoch 8/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.2049 - acc: 0.0659 - val_loss: 0.6244 - val_acc: 0.0182
# Epoch 9/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.1809 - acc: 0.0696 - val_loss: 0.6189 - val_acc: 0.0175
# Epoch 10/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.1598 - acc: 0.0736 - val_loss: 0.6340 - val_acc: 0.0195
#
# Epoch 00010: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/ag_questionTypes_as_input_100_150_200_cpu.model2
# Epoch 11/20
# 1600/1600 [==============================] - 26s 17ms/step - loss: 0.1405 - acc: 0.0782 - val_loss: 0.6470 - val_acc: 0.0178
# Epoch 12/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.1245 - acc: 0.0814 - val_loss: 0.6642 - val_acc: 0.0165
# Epoch 13/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.1115 - acc: 0.0835 - val_loss: 0.6634 - val_acc: 0.0182
# Epoch 14/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.0990 - acc: 0.0860 - val_loss: 0.6867 - val_acc: 0.0178
# Epoch 15/20
# 1100/1600 [===================>..........] - ETA: 7s - loss: 0.0903 - acc: 0.0886

# %%
# test the AG model with question types as input
# load the trained model and test

from keras.models import load_model

filename = "ag_questionTypes_as_input_100_150_200_cpu.model"
file_saved_model = os.path.join(output_path, filename)
model = load_model(file_saved_model)
print(model.summary())

# get some data and make prediction
data = get_train_data(0, 30)
qdata = data["questionType_data"]
adata = data["answer_data"]
media_data = data["media_data"]

answers_predicted = model.predict({'text': qdata, 'media': media_data})

print ("answers_predicted.shape = ", answers_predicted.shape)
print ("type(answers_predicted) = ", type(answers_predicted))

print ("answers_predicted[0, :] = ", answers_predicted[0, :])

answer_text = list_matrices_to_list_texts(answers_predicted)
qdata_text = list_matrices_to_list_question_types(qdata)
adata_text = list_matrices_to_list_texts(adata)
for i in range(len(qdata)):
  print("\nquestion type: ", qdata_text[i])
  print("given answer: ", adata_text[i])
  print ("predicted_answer = ", answer_text[i])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               (None, 1, 65)        0
# __________________________________________________________________________________________________
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 100)          66400       text[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 250)          0           lstm_4[0][0]
#                                                                  lstm_5[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 10, 250)      0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 10, 200)      360800      repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 10, 3200)     643200      lstm_6[0][0]
# ==================================================================================================
# Total params: 2,389,800
# Trainable params: 2,389,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# len(list_found) = 30, len(list_image_ids) = 30
# buffer (794) not filled up.
# image_data.shape = (30, 70, 2048)
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# answers_predicted.shape =  (30, 10, 3200)
# type(answers_predicted) =  <class 'numpy.ndarray'>
# answers_predicted[0, :] =  [[8.3741288e-06 8.5435383e-02 7.1547224e-06 ... 6.5843724e-06
#   7.8716066e-06 6.9592406e-06]
#  [3.2601777e-06 9.5741853e-02 3.6544063e-06 ... 2.8588727e-06
#   3.9746137e-06 3.5496416e-06]
#  [6.4464066e-06 4.1045595e-02 6.4173687e-06 ... 5.3496747e-06
#   7.2184903e-06 5.7302627e-06]
#  ...
#  [8.3723216e-06 2.6125358e-02 7.4225536e-06 ... 5.7774441e-06
#   8.7494836e-06 6.9157504e-06]
#  [8.6860655e-06 2.5941433e-02 7.6330152e-06 ... 5.9197737e-06
#   9.0560316e-06 7.1374370e-06]
#  [8.8530414e-06 2.5865659e-02 7.7446375e-06 ... 5.9890453e-06
#   9.2193777e-06 7.2528778e-06]]
#
# question type:  what is this
# given answer:  net REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN white white white white white white white
#
# question type:  what
# given answer:  pitcher REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN and white white white white white white white white
#
# question type:  what color is the
# given answer:  orange REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  white and white white white white white white white white
#
# question type:  is this
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yes no no no no no no
#
# question type:  what color is the
# given answer:  white REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  white and white white white white white white white white
#
# question type:  what is the person
# given answer:  skiing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN and white white white white white white white white
#
# question type:  what color is the
# given answer:  red REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  white and white white white white white white white white
#
# question type:  what is in the
# given answer:  frisbee REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN white white white white white white white white
#
# question type:  is the
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  is the
# given answer:  frisbee REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  is the
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  is there
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  what is the
# given answer:  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN white white white white white white white white
#
# question type:  is the
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  what color is the
# given answer:  white and purple REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  white and white white white white white white white white
#
# question type:  what is the
# given answer:  brushing teeth REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN white white white white white white white white
#
# question type:  is
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yellow yellow yellow yellow yellow yellow yellow
#
# question type:  is the man
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yellow yellow yellow yellow yellow yellow yellow yellow
#
# question type:  what is the
# given answer:  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN white white white white white white white white
#
# question type:  none of the above
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  no and yellow yellow yellow yellow yellow yellow yellow yellow
#
# question type:  does the
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and no yellow yellow yellow yellow yellow yellow yellow
#
# question type:  is this
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yes yes no no no no no no
#
# question type:  is the man
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yellow yellow yellow yellow yellow yellow yellow yellow
#
# question type:  none of the above
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  no and yellow yellow yellow yellow yellow yellow yellow yellow
#
# question type:  what
# given answer:  black and white REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN and white white white white white white white white
#
# question type:  are the
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and no yellow yellow yellow yellow yellow yellow yellow
#
# question type:  was
# given answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and yellow yellow yellow yellow yellow yellow yellow yellow
#
# question type:  does the
# given answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  yes and no yellow yellow yellow yellow yellow yellow yellow
#
# question type:  what is this
# given answer:  skateboard REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN white white white white white white white
#
# question type:  how many
# given answer:  1 REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_answer =  1 REMOVEDTOKEN 1 1 1 1 1 1 1 1

# %%
# construct question generator model
# which is basically the same as the AG model except input and output are different

from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.models import load_model
import pandas as pd
import os

# Note that the inputs are answer and media, and output is question
params={
    "GPU": False,    
    "lr":0.001,
    "text_shape":(MAX_ANSWER_LENGTH, MAX_NUM_WORDS), # answer text
    "media_shape":(MEDIA_MAX_LENGTH, MEDIA_FEATURE_DIMENSION),
    "output_shape1": MAX_QUESTION_LENGTH, # output length
    "output_shape2": MAX_NUM_WORDS, # number of possible words
    "layer_1_text_input_neuron": 100,
    "layer_1_media_input_neuron": 150,
    "concatenated_layer_neuron": 200,
}

# get data and train

file_saved_model = os.path.join(output_path, "qg_100_150_200_cpu.model2")
if os.path.isfile(file_saved_model):
  print ("load model from ", file_saved_model)
  model_qg = load_model(file_saved_model) # continue from last checkpoint
else:
  model_qg = set_up_model(params)

print(model_qg.summary())

# save every n epoches
checkpoint = ModelCheckpoint(file_saved_model, monitor='acc', verbose=1, save_best_only=False, mode='max', period=10)

ndata = len(qa_df)

# size = 500 # for testing
size = 2000

# start from last round
start = size * 156

n_rounds_for_1_pass = int(ndata/size) + 1
print ("n_rounds_for_1_pass = ", n_rounds_for_1_pass)

# fetch data section by section so that it won't use up all the ram
for i in range( n_rounds_for_1_pass * 300 ):
  print ("running round ", i)

  # make sure validation data is the same after 1 pass of the whole data
  if start >= ndata:
    start = 0
  print ("start: {} (total data = {})".format(start, ndata))

  qdata, adata, media_data = get_train_data_qam(start, start+size)
  start = start + size

  if (len(qdata) != len(media_data)) or len(qdata) == 0:
    print( "len(qdata) ({}) != len(media_data) ({}). likely the part to get images has some issues. skip this section of data.".format( len(qdata), len(media_data) ) )
    continue

  train_size = int(0.8 * len(qdata))
  qdata_train = qdata[0:train_size]
  qdata_test = qdata[train_size:]
  adata_train = adata[0:train_size]
  adata_test = adata[train_size:]
  media_data_train = media_data[0:train_size]
  media_data_test = media_data[train_size:]

  print ("qdata_train.shape = ", qdata_train.shape)
  print ("qdata_test.shape = ", qdata_test.shape)
  print ("adata_train.shape = ", adata_train.shape)
  print ("adata_test.shape = ", adata_test.shape)
  print ("media_data_train.shape = ", media_data_train.shape)
  print ("media_data_test.shape = ", media_data_test.shape)

  if i % 10 == 0 and os.path.isfile(file_saved_model):
    # reload the model from file once in a while, in case the .fit() function buffers too much data
    model_qg = None
    model_qg = load_model(file_saved_model)
    print ("reload model from file")

  out=model_qg.fit({'text': adata_train, 'media': media_data_train}, 
                qdata_train, 
                epochs=20,
                batch_size=20, 
                validation_data=({'text': adata_test, 'media': media_data_test}, qdata_test), 
                verbose=1,
                callbacks=[checkpoint])
# Out:
# Streaming output truncated to the last 5000 lines.
# remove image (last accessed time, image id) = (1587227298.1227336, 360129)
# remove image (last accessed time, image id) = (1587226253.20252, 358915)
# remove image (last accessed time, image id) = (1587228824.4239643, 100078)
# remove image (last accessed time, image id) = (1587238894.2621481, 374018)
# remove image (last accessed time, image id) = (1587250492.2032132, 125473)
# remove image (last accessed time, image id) = (1587235664.4692457, 369886)
# remove image (last accessed time, image id) = (1587242623.4730105, 222097)
# remove image (last accessed time, image id) = (1587253147.8808484, 390287)
# remove image (last accessed time, image id) = (1587227804.417472, 491826)
# remove image (last accessed time, image id) = (1587236202.3611832, 108375)
# remove image (last accessed time, image id) = (1587245779.0514624, 250929)
# remove image (last accessed time, image id) = (1587238891.6080625, 373444)
# remove image (last accessed time, image id) = (1587227299.275388, 360396)
# remove image (last accessed time, image id) = (1587251540.0734875, 545411)
# remove image (last accessed time, image id) = (1587228309.8019888, 361518)
# remove image (last accessed time, image id) = (1587257396.1494389, 132908)
# remove image (last accessed time, image id) = (1587221561.6754677, 517690)
# remove image (last accessed time, image id) = (1587221009.3723843, 483695)
# remove image (last accessed time, image id) = (1587221009.0428014, 473815)
# remove image (last accessed time, image id) = (1587235125.1969104, 105282)
# remove image (last accessed time, image id) = (1587238352.019496, 241797)
# remove image (last accessed time, image id) = (1587252061.61723, 258129)
# remove image (last accessed time, image id) = (1587248394.162887, 254129)
# remove image (last accessed time, image id) = (1587256861.2063951, 394776)
# remove image (last accessed time, image id) = (1587241550.3307853, 245733)
# remove image (last accessed time, image id) = (1587238353.28018, 110982)
# remove image (last accessed time, image id) = (1587228308.6072042, 409732)
# remove image (last accessed time, image id) = (1587223138.1629534, 355368)
# remove image (last accessed time, image id) = (1587241021.145129, 507351)
# remove image (last accessed time, image id) = (1587256861.480185, 263762)
# remove image (last accessed time, image id) = (1587237817.427168, 110000)
# remove image (last accessed time, image id) = (1587254240.784088, 260955)
# remove image (last accessed time, image id) = (1587235663.807063, 304735)
# remove image (last accessed time, image id) = (1587231447.8756156, 405709)
# remove image (last accessed time, image id) = (1587231978.583654, 496746)
# remove image (last accessed time, image id) = (1587234594.5899317, 106902)
# remove image (last accessed time, image id) = (1587228308.7517455, 361275)
# remove image (last accessed time, image id) = (1587240489.9234028, 171875)
# remove image (last accessed time, image id) = (1587230389.7707734, 101686)
# remove image (last accessed time, image id) = (1587256318.508943, 393985)
# remove image (last accessed time, image id) = (1587246295.8315585, 478845)
# remove image (last accessed time, image id) = (1587228823.9571366, 99981)
# remove image (last accessed time, image id) = (1587252587.4177277, 520898)
# remove image (last accessed time, image id) = (1587246812.4630418, 513861)
# remove image (last accessed time, image id) = (1587236743.0138874, 109314)
# remove image (last accessed time, image id) = (1587237819.5319154, 372535)
# remove image (last accessed time, image id) = (1587252588.4628892, 261765)
# remove image (last accessed time, image id) = (1587251539.6072366, 458016)
# remove image (last accessed time, image id) = (1587246295.5090532, 413300)
# remove image (last accessed time, image id) = (1587254782.4168925, 392180)
# remove image (last accessed time, image id) = (1587222107.5987508, 222703)
# remove image (last accessed time, image id) = (1587251014.6247315, 125720)
# remove image (last accessed time, image id) = (1587255789.4735003, 262329)
# remove image (last accessed time, image id) = (1587248393.7620199, 385130)
# remove image (last accessed time, image id) = (1587245255.2947655, 381377)
# remove image (last accessed time, image id) = (1587234592.6071198, 476501)
# remove image (last accessed time, image id) = (1587244204.6740813, 392363)
# remove image (last accessed time, image id) = (1587255324.6429987, 261669)
# remove image (last accessed time, image id) = (1587226775.9776318, 359726)
# remove image (last accessed time, image id) = (1587245779.3459823, 194748)
# remove image (last accessed time, image id) = (1587248393.3443685, 212893)
# remove image (last accessed time, image id) = (1587230389.074993, 560204)
# remove image (last accessed time, image id) = (1587254239.0641205, 309829)
# remove image (last accessed time, image id) = (1587247340.4581747, 121659)
# remove image (last accessed time, image id) = (1587253696.819216, 128905)
# remove image (last accessed time, image id) = (1587224696.322171, 225667)
# remove image (last accessed time, image id) = (1587238892.845087, 504769)
# remove image (last accessed time, image id) = (1587238352.583963, 504057)
# remove image (last accessed time, image id) = (1587236203.4434059, 370736)
# remove image (last accessed time, image id) = (1587253150.0935695, 521800)
# remove image (last accessed time, image id) = (1587244729.975693, 63414)
# remove image (last accessed time, image id) = (1587247871.050605, 122274)
# remove image (last accessed time, image id) = (1587236202.4460282, 422603)
# remove image (last accessed time, image id) = (1587253148.954978, 259414)
# remove image (last accessed time, image id) = (1587241020.789132, 245118)
# remove image (last accessed time, image id) = (1587221008.8332896, 90341)
# remove image (last accessed time, image id) = (1587253150.1391833, 458339)
# remove image (last accessed time, image id) = (1587243156.1349926, 116854)
# remove image (last accessed time, image id) = (1587244731.08969, 265819)
# remove image (last accessed time, image id) = (1587249969.085948, 124751)
# remove image (last accessed time, image id) = (1587224698.2709193, 430890)
# remove image (last accessed time, image id) = (1587245255.907866, 119358)
# remove image (last accessed time, image id) = (1587247340.2643104, 121618)
# remove image (last accessed time, image id) = (1587255791.1482558, 262619)
# remove image (last accessed time, image id) = (1587222625.438167, 485499)
# remove image (last accessed time, image id) = (1587252587.9867582, 127799)
# remove image (last accessed time, image id) = (1587221010.8417566, 484110)
# remove image (last accessed time, image id) = (1587222107.75555, 353809)
# remove image (last accessed time, image id) = (1587234594.548676, 369036)
# remove image (last accessed time, image id) = (1587237817.5640075, 411554)
# remove image (last accessed time, image id) = (1587226251.9880536, 96512)
# remove image (last accessed time, image id) = (1587240488.7726738, 565053)
# remove image (last accessed time, image id) = (1587235125.5732098, 500694)
# remove image (last accessed time, image id) = (1587253696.4590943, 390966)
# remove image (last accessed time, image id) = (1587244729.0521312, 128921)
# remove image (last accessed time, image id) = (1587248913.2207766, 183048)
# remove image (last accessed time, image id) = (1587230390.6004694, 495051)
# remove image (last accessed time, image id) = (1587235123.3850534, 238070)
# remove image (last accessed time, image id) = (1587223660.3277144, 321495)
# remove image (last accessed time, image id) = (1587241022.2551963, 376505)
# remove image (last accessed time, image id) = (1587242623.1572585, 378323)
# remove image (last accessed time, image id) = (1587249968.6297612, 466790)
# remove image (last accessed time, image id) = (1587231450.1488802, 496430)
# remove image (last accessed time, image id) = (1587222107.9789984, 353858)
# remove image (last accessed time, image id) = (1587245779.1534574, 513093)
# remove image (last accessed time, image id) = (1587227298.131279, 229058)
# remove image (last accessed time, image id) = (1587249443.3021238, 255317)
# remove image (last accessed time, image id) = (1587245779.5928059, 513174)
# remove image (last accessed time, image id) = (1587221009.0769668, 352535)
# remove image (last accessed time, image id) = (1587234593.4535077, 368818)
# remove image (last accessed time, image id) = (1587228308.946301, 230246)
# remove image (last accessed time, image id) = (1587243680.6300504, 379246)
# remove image (last accessed time, image id) = (1587256319.6478448, 394208)
# remove image (last accessed time, image id) = (1587242622.9397132, 378278)
# remove image (last accessed time, image id) = (1587233009.9148932, 498175)
# remove image (last accessed time, image id) = (1587242083.2916229, 246677)
# remove image (last accessed time, image id) = (1587248914.8867683, 385700)
# remove image (last accessed time, image id) = (1587227299.0156944, 491400)
# remove image (last accessed time, image id) = (1587237818.1479383, 372288)
# remove image (last accessed time, image id) = (1587251538.8314898, 519713)
# remove image (last accessed time, image id) = (1587245778.4847276, 381890)
# remove image (last accessed time, image id) = (1587222625.0190783, 168282)
# remove image (last accessed time, image id) = (1587222626.6914704, 354699)
# remove image (last accessed time, image id) = (1587238354.5322018, 242325)
# remove image (last accessed time, image id) = (1587237277.1790087, 109862)
# remove image (last accessed time, image id) = (1587252588.0564666, 292314)
# remove image (last accessed time, image id) = (1587225219.743438, 226695)
# remove image (last accessed time, image id) = (1587230390.74684, 126204)
# remove image (last accessed time, image id) = (1587253150.7472177, 390856)
# remove image (last accessed time, image id) = (1587241021.7378368, 150114)
# remove image (last accessed time, image id) = (1587244203.725516, 510768)
# remove image (last accessed time, image id) = (1587234593.1714578, 106616)
# remove image (last accessed time, image id) = (1587243154.9387488, 509815)
# remove image (last accessed time, image id) = (1587229863.0838614, 410096)
# remove image (last accessed time, image id) = (1587222108.5752788, 353991)
# remove image (last accessed time, image id) = (1587251539.4959133, 327191)
# remove image (last accessed time, image id) = (1587228823.5302763, 99888)
# remove image (last accessed time, image id) = (1587252062.299017, 152269)
# remove image (last accessed time, image id) = (1587254239.052923, 283730)
# remove image (last accessed time, image id) = (1587254783.6943772, 130295)
# remove image (last accessed time, image id) = (1587249968.9717708, 124732)
# remove image (last accessed time, image id) = (1587227804.914268, 491959)
# remove image (last accessed time, image id) = (1587234594.526717, 126409)
# remove image (last accessed time, image id) = (1587239962.3838868, 375086)
# remove image (last accessed time, image id) = (1587230390.58764, 232906)
# remove image (last accessed time, image id) = (1587235124.6723258, 238352)
# remove image (last accessed time, image id) = (1587253698.1978807, 391332)
# remove image (last accessed time, image id) = (1587249969.5336888, 501002)
# remove image (last accessed time, image id) = (1587254239.5270467, 391754)
# remove image (last accessed time, image id) = (1587244206.2098205, 63370)
# remove image (last accessed time, image id) = (1587228824.326248, 100050)
# remove image (last accessed time, image id) = (1587227299.3514373, 103759)
# remove image (last accessed time, image id) = (1587229863.4645836, 494574)
# remove image (last accessed time, image id) = (1587252589.2287862, 259113)
# remove image (last accessed time, image id) = (1587223137.9981492, 566126)
# remove image (last accessed time, image id) = (1587254782.7475376, 130100)
# remove image (last accessed time, image id) = (1587243680.4998333, 366153)
# remove image (last accessed time, image id) = (1587228822.4600053, 361778)
# remove image (last accessed time, image id) = (1587246293.2498477, 120006)
# remove image (last accessed time, image id) = (1587223138.7081268, 203876)
# remove image (last accessed time, image id) = (1587236203.772247, 549183)
# remove image (last accessed time, image id) = (1587254239.5194488, 524044)
# remove image (last accessed time, image id) = (1587247340.3696492, 379399)
# remove image (last accessed time, image id) = (1587248393.4165044, 370012)
# remove image (last accessed time, image id) = (1587253148.9507291, 390483)
# remove image (last accessed time, image id) = (1587222107.290734, 353707)
# remove image (last accessed time, image id) = (1587239962.5951834, 244055)
# remove image (last accessed time, image id) = (1587225738.0338533, 227502)
# remove image (last accessed time, image id) = (1587226252.7075691, 96679)
# remove image (last accessed time, image id) = (1587250492.240648, 187488)
# remove image (last accessed time, image id) = (1587242622.596651, 509269)
# remove image (last accessed time, image id) = (1587251539.9965131, 519942)
# remove image (last accessed time, image id) = (1587249969.1534503, 20794)
# remove image (last accessed time, image id) = (1587242621.440181, 509034)
# remove image (last accessed time, image id) = (1587223659.8945765, 356006)
# remove image (last accessed time, image id) = (1587237275.531582, 240608)
# remove image (last accessed time, image id) = (1587222627.0837474, 485852)
# remove image (last accessed time, image id) = (1587228309.0309951, 99191)
# remove image (last accessed time, image id) = (1587235666.2083228, 108112)
# remove image (last accessed time, image id) = (1587237275.7588923, 502792)
# remove image (last accessed time, image id) = (1587231979.0959842, 103642)
# remove image (last accessed time, image id) = (1587226776.0215855, 369869)
# remove image (last accessed time, image id) = (1587222626.6432302, 190187)
# remove image (last accessed time, image id) = (1587256861.3330636, 1586)
# remove image (last accessed time, image id) = (1587237819.1206787, 503535)
# remove image (last accessed time, image id) = (1587250490.6528385, 518390)
# remove image (last accessed time, image id) = (1587251014.8335617, 173876)
# remove image (last accessed time, image id) = (1587227805.8424275, 492151)
# remove image (last accessed time, image id) = (1587242082.3326073, 565365)
# remove image (last accessed time, image id) = (1587223137.941658, 224243)
# remove image (last accessed time, image id) = (1587234592.1627731, 237474)
# remove image (last accessed time, image id) = (1587221009.5487702, 233543)
# remove image (last accessed time, image id) = (1587229340.9713259, 404877)
# remove image (last accessed time, image id) = (1587227297.502301, 81842)
# remove image (last accessed time, image id) = (1587253697.987516, 283666)
# remove image (last accessed time, image id) = (1587237275.7704487, 109580)
# remove image (last accessed time, image id) = (1587225736.562788, 96091)
# remove image (last accessed time, image id) = (1587226253.194604, 489986)
# remove image (last accessed time, image id) = (1587257395.9058576, 1781)
# remove image (last accessed time, image id) = (1587251014.8573916, 387901)
# remove image (last accessed time, image id) = (1587221010.3913016, 473879)
# remove image (last accessed time, image id) = (1587234593.545069, 499913)
# remove image (last accessed time, image id) = (1587238893.7870605, 504980)
# remove image (last accessed time, image id) = (1587253697.3323257, 371029)
# remove image (last accessed time, image id) = (1587235125.5112886, 237271)
# remove image (last accessed time, image id) = (1587241021.5448732, 202400)
# remove image (last accessed time, image id) = (1587252061.0403516, 389103)
# remove image (last accessed time, image id) = (1587239431.8014414, 505418)
# remove image (last accessed time, image id) = (1587253696.908367, 391074)
# remove image (last accessed time, image id) = (1587247872.3798347, 122560)
# remove image (last accessed time, image id) = (1587236201.5712311, 108187)
# remove image (last accessed time, image id) = (1587221010.4870434, 352938)
# remove image (last accessed time, image id) = (1587240487.8207293, 412101)
# remove image (last accessed time, image id) = (1587256319.0792322, 131961)
# remove image (last accessed time, image id) = (1587222109.889664, 354237)
# After removing old items, len(image_data_buffer) =  20000
# image_data.shape = (2000, 70, 2048)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# qdata_train.shape =  (1600, 25, 3200)
# qdata_test.shape =  (400, 25, 3200)
# adata_train.shape =  (1600, 10, 3200)
# adata_test.shape =  (400, 10, 3200)
# media_data_train.shape =  (1600, 70, 2048)
# media_data_test.shape =  (400, 70, 2048)
# Train on 1600 samples, validate on 400 samples
# Epoch 1/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 1.0004 - acc: 0.0838 - val_loss: 0.9590 - val_acc: 0.0831
# Epoch 2/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.8836 - acc: 0.0910 - val_loss: 0.9527 - val_acc: 0.0835
# Epoch 3/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.8366 - acc: 0.0963 - val_loss: 0.9627 - val_acc: 0.0838
# Epoch 4/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.8015 - acc: 0.0988 - val_loss: 0.9777 - val_acc: 0.0822
# Epoch 5/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.7757 - acc: 0.1020 - val_loss: 0.9889 - val_acc: 0.0828
# Epoch 6/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.7556 - acc: 0.1026 - val_loss: 1.0042 - val_acc: 0.0814
# Epoch 7/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.7328 - acc: 0.1059 - val_loss: 1.0152 - val_acc: 0.0815
# Epoch 8/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.7130 - acc: 0.1089 - val_loss: 1.0359 - val_acc: 0.0818
# Epoch 9/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6955 - acc: 0.1100 - val_loss: 1.0419 - val_acc: 0.0798
# Epoch 10/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6801 - acc: 0.1124 - val_loss: 1.0591 - val_acc: 0.0791
#
# Epoch 00010: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/qg_100_150_200_cpu.model
# Epoch 11/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6684 - acc: 0.1130 - val_loss: 1.0663 - val_acc: 0.0808
# Epoch 12/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6538 - acc: 0.1149 - val_loss: 1.0852 - val_acc: 0.0785
# Epoch 13/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6398 - acc: 0.1164 - val_loss: 1.0957 - val_acc: 0.0785
# Epoch 14/20
# 1600/1600 [==============================] - 28s 17ms/step - loss: 0.6251 - acc: 0.1185 - val_loss: 1.0849 - val_acc: 0.0782
# Epoch 15/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.6117 - acc: 0.1201 - val_loss: 1.1390 - val_acc: 0.0770
# Epoch 16/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.5938 - acc: 0.1233 - val_loss: 1.1395 - val_acc: 0.0771
# Epoch 17/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.5830 - acc: 0.1250 - val_loss: 1.1551 - val_acc: 0.0756
# Epoch 18/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.5737 - acc: 0.1254 - val_loss: 1.1547 - val_acc: 0.0763
# Epoch 19/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.5620 - acc: 0.1277 - val_loss: 1.1944 - val_acc: 0.0764
# Epoch 20/20
# 1600/1600 [==============================] - 27s 17ms/step - loss: 0.5506 - acc: 0.1306 - val_loss: 1.1886 - val_acc: 0.0750
#
# Epoch 00020: saving model to /content/gdrive/My Drive/cs6240_project_codes/outputs/qg_100_150_200_cpu.model
# running round  70
# start: 8000 (total data = 443757)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# len(list_found) = 2000, len(list_image_ids) = 2000
# To remove 379 items from buffer with size 20379
# remove image (last accessed time, image id) = (1587245779.5079796, 502949)
# remove image (last accessed time, image id) = (1587253150.5802069, 39201)
# remove image (last accessed time, image id) = (1587223659.2589386, 224781)
# remove image (last accessed time, image id) = (1587225737.2470858, 212648)
# remove image (last accessed time, image id) = (1587228310.2633705, 366103)
# remove image (last accessed time, image id) = (1587224180.693134, 59394)
# remove image (last accessed time, image id) = (1587255791.2007015, 21926)
# remove image (last accessed time, image id) = (1587253697.3571033, 391170)
# remove image (last accessed time, image id) = (1587257945.786102, 568455)
# remove image (last accessed time, image id) = (1587232493.5173187, 235529)
# remove image (last accessed time, image id) = (1587239431.6527433, 193456)
# remove image (last accessed time, image id) = (1587241549.8794682, 507776)
# remove image (last accessed time, image id) = (1587244205.5771189, 558221)
# remove image (last accessed time, image id) = (1587221561.1226237, 102610)
# remove image (last accessed time, image id) = (1587230389.9762, 519398)
# remove image (last accessed time, image id) = (1587255326.6231463, 262118)
# remove image (last accessed time, image id) = (1587248392.763851, 516000)
# remove image (last accessed time, image id) = (1587246814.7307234, 151265)
# remove image (last accessed time, image id) = (1587245778.5853565, 512983)
# remove image (last accessed time, image id) = (1587245779.30805, 119904)
# remove image (last accessed time, image id) = (1587248914.7245717, 385666)
# remove image (last accessed time, image id) = (1587228822.1577902, 213203)
# remove image (last accessed time, image id) = (1587241022.799785, 245560)
# remove image (last accessed time, image id) = (1587236201.8133912, 370391)
# remove image (last accessed time, image id) = (1587231450.4294136, 234350)
# remove image (last accessed time, image id) = (1587255324.4481962, 305499)
# remove image (last accessed time, image id) = (1587257398.2308362, 264406)
# remove image (last accessed time, image id) = (1587230389.7537627, 101684)
# remove image (last accessed time, image id) = (1587257944.3536158, 526861)
# remove image (last accessed time, image id) = (1587243154.0358992, 247493)
# remove image (last accessed time, image id) = (1587256859.2407415, 263333)
# remove image (last accessed time, image id) = (1587245778.1987252, 512904)
# remove image (last accessed time, image id) = (1587256319.8281934, 322979)
# remove image (last accessed time, image id) = (1587252063.3033981, 405873)
# remove image (last accessed time, image id) = (1587254784.123373, 523608)
# remove image (last accessed time, image id) = (1587239960.9640007, 324605)
# remove image (last accessed time, image id) = (1587225219.1667972, 226583)
# remove image (last accessed time, image id) = (1587232492.8072512, 497519)
# remove image (last accessed time, image id) = (1587244205.2291718, 270160)
# remove image (last accessed time, image id) = (1587257398.4481742, 284373)
# remove image (last accessed time, image id) = (1587249969.2586796, 463467)
# remove image (last accessed time, image id) = (1587248915.4802177, 385803)
# remove image (last accessed time, image id) = (1587248915.322018, 254701)
# remove image (last accessed time, image id) = (1587255325.2825258, 371315)
# remove image (last accessed time, image id) = (1587256317.523007, 595)
# remove image (last accessed time, image id) = (1587221009.2001772, 483639)
# remove image (last accessed time, image id) = (1587223137.457935, 224136)
# remove image (last accessed time, image id) = (1587237819.846224, 241522)
# remove image (last accessed time, image id) = (1587250490.6873996, 125184)
# remove image (last accessed time, image id) = (1587237820.5106766, 95337)
# remove image (last accessed time, image id) = (1587235124.3799245, 84512)
# remove image (last accessed time, image id) = (1587229341.4368277, 366268)
# remove image (last accessed time, image id) = (1587255789.9071155, 131342)
# remove image (last accessed time, image id) = (1587244730.2061427, 380520)
# remove image (last accessed time, image id) = (1587256317.615296, 393826)
# remove image (last accessed time, image id) = (1587254783.2896726, 523433)
# remove image (last accessed time, image id) = (1587232492.9147844, 366473)
# remove image (last accessed time, image id) = (1587239432.5780923, 326716)
# remove image (last accessed time, image id) = (1587251540.4676263, 388961)
# remove image (last accessed time, image id) = (1587237275.2744095, 109483)
# remove image (last accessed time, image id) = (1587238893.040181, 373737)
# remove image (last accessed time, image id) = (1587228822.996411, 99753)
# remove image (last accessed time, image id) = (1587243155.2728055, 509876)
# remove image (last accessed time, image id) = (1587233008.7499979, 104696)
# remove image (last accessed time, image id) = (1587245776.660023, 491426)
# remove image (last accessed time, image id) = (1587248915.2906828, 385765)
# remove image (last accessed time, image id) = (1587256860.979284, 415314)
# remove image (last accessed time, image id) = (1587227298.2093635, 365858)
# remove image (last accessed time, image id) = (1587238352.9637592, 373063)
# remove image (last accessed time, image id) = (1587221561.1902726, 473983)
# remove image (last accessed time, image id) = (1587236202.5972047, 501638)
# remove image (last accessed time, image id) = (1587241021.064976, 507334)
# remove image (last accessed time, image id) = (1587247871.6356268, 103817)
# remove image (last accessed time, image id) = (1587248913.6371088, 254362)
# remove image (last accessed time, image id) = (1587255790.282037, 131400)
# remove image (last accessed time, image id) = (1587238352.999845, 110926)
# remove image (last accessed time, image id) = (1587253149.859678, 259595)
# remove image (last accessed time, image id) = (1587243155.278197, 128670)
# remove image (last accessed time, image id) = (1587225218.0835774, 226345)
# remove image (last accessed time, image id) = (1587233009.7472174, 367071)
# remove image (last accessed time, image id) = (1587225218.553961, 15895)
# remove image (last accessed time, image id) = (1587242622.2328465, 565462)
# remove image (last accessed time, image id) = (1587249441.7924988, 123916)
# remove image (last accessed time, image id) = (1587227804.7120998, 491904)
# remove image (last accessed time, image id) = (1587253697.605849, 129067)
# remove image (last accessed time, image id) = (1587251540.5845466, 257923)
# remove image (last accessed time, image id) = (1587221009.8694053, 386475)
# remove image (last accessed time, image id) = (1587249970.2644603, 518215)
# remove image (last accessed time, image id) = (1587222624.8368688, 92153)
# remove image (last accessed time, image id) = (1587225735.6239095, 226961)
# remove image (last accessed time, image id) = (1587224181.8997102, 225557)
# remove image (last accessed time, image id) = (1587230389.1214995, 494780)
# remove image (last accessed time, image id) = (1587246813.7813282, 252010)
# remove image (last accessed time, image id) = (1587243681.2091556, 510434)
# remove image (last accessed time, image id) = (1587234055.4305105, 237110)
# remove image (last accessed time, image id) = (1587248913.7337263, 279071)
# remove image (last accessed time, image id) = (1587233529.2852786, 104977)
# remove image (last accessed time, image id) = (1587241551.683155, 377056)
# remove image (last accessed time, image id) = (1587248393.3722615, 122913)
# remove image (last accessed time, image id) = (1587248915.3046675, 516840)
# remove image (last accessed time, image id) = (1587228307.7203815, 98956)
# remove image (last accessed time, image id) = (1587223658.154412, 474331)
# remove image (last accessed time, image id) = (1587253696.0929258, 436519)
# remove image (last accessed time, image id) = (1587249970.1056507, 435889)
# remove image (last accessed time, image id) = (1587228824.2065353, 169589)
# remove image (last accessed time, image id) = (1587227298.900297, 360302)
# remove image (last accessed time, image id) = (1587252062.9065356, 520515)
# remove image (last accessed time, image id) = (1587246294.8485029, 382503)
# remove image (last accessed time, image id) = (1587240488.0470939, 375500)
# remove image (last accessed time, image id) = (1587247871.5796099, 253464)
# remove image (last accessed time, image id) = (1587248914.0564244, 123378)
# remove image (last accessed time, image id) = (1587243681.9801705, 510594)
# remove image (last accessed time, image id) = (1587230918.7316175, 475815)
# remove image (last accessed time, image id) = (1587233009.6337411, 17483)
# remove image (last accessed time, image id) = (1587234055.5184107, 368205)
# remove image (last accessed time, image id) = (1587225737.620292, 81591)
# remove image (last accessed time, image id) = (1587250492.939653, 130163)
# remove image (last accessed time, image id) = (1587246296.1922925, 251697)
# remove image (last accessed time, image id) = (1587230390.0179784, 232809)
# remove image (last accessed time, image id) = (1587254240.8567626, 523109)
# remove image (last accessed time, image id) = (1587223137.3506012, 304250)
# remove image (last accessed time, image id) = (1587238891.9321587, 521003)
# remove image (last accessed time, image id) = (1587255325.130061, 523923)
# remove image (last accessed time, image id) = (1587251538.5698152, 523515)
# remove image (last accessed time, image id) = (1587234594.6184049, 454725)
# remove image (last accessed time, image id) = (1587241021.1202939, 368547)
# remove image (last accessed time, image id) = (1587224696.6209466, 496373)
# remove image (last accessed time, image id) = (1587251014.8605378, 26010)
# remove image (last accessed time, image id) = (1587256318.1052368, 393915)
# remove image (last accessed time, image id) = (1587246814.9956236, 383368)
# remove image (last accessed time, image id) = (1587247872.2810848, 122537)
# remove image (last accessed time, image id) = (1587245776.9977698, 250526)
# remove image (last accessed time, image id) = (1587230918.916967, 364566)
# remove image (last accessed time, image id) = (1587225738.0180736, 492037)
# remove image (last accessed time, image id) = (1587223658.0604737, 224522)
# remove image (last accessed time, image id) = (1587226251.9971535, 227587)
# remove image (last accessed time, image id) = (1587222626.7930987, 485788)
# remove image (last accessed time, image id) = (1587243679.8586524, 248023)
# remove image (last accessed time, image id) = (1587248914.673705, 123512)
# remove image (last accessed time, image id) = (1587238891.5531085, 344138)
# remove image (last accessed time, image id) = (1587229862.505201, 232230)
# remove image (last accessed time, image id) = (1587252061.978847, 510517)
# remove image (last accessed time, image id) = (1587232493.5725105, 366614)
# remove image (last accessed time, image id) = (1587249970.2994344, 125009)
# remove image (last accessed time, image id) = (1587254240.528054, 260888)
# remove image (last accessed time, image id) = (1587249967.5090258, 39236)
# remove image (last accessed time, image id) = (1587230918.88954, 169262)
# remove image (last accessed time, image id) = (1587257398.0650015, 526522)
# remove image (last accessed time, image id) = (1587243680.903227, 510368)
# remove image (last accessed time, image id) = (1587231448.7827797, 234006)
# remove image (last accessed time, image id) = (1587257395.8522673, 1774)
# remove image (last accessed time, image id) = (1587243155.7872183, 116783)
# remove image (last accessed time, image id) = (1587221010.0761204, 90679)
# remove image (last accessed time, image id) = (1587234056.2162287, 106222)
# remove image (last accessed time, image id) = (1587251540.459276, 126816)
# remove image (last accessed time, image id) = (1587230389.5054886, 101630)
# remove image (last accessed time, image id) = (1587255788.7163637, 262187)
# remove image (last accessed time, image id) = (1587236742.9849567, 531450)
# remove image (last accessed time, image id) = (1587221010.2634127, 221803)
# remove image (last accessed time, image id) = (1587247340.1274495, 252664)
# remove image (last accessed time, image id) = (1587233528.0695052, 132883)
# remove image (last accessed time, image id) = (1587245778.2054434, 151020)
# remove image (last accessed time, image id) = (1587254782.0445688, 29671)
# remove image (last accessed time, image id) = (1587223659.2829282, 355863)
# remove image (last accessed time, image id) = (1587257943.2389786, 2374)
# remove image (last accessed time, image id) = (1587238353.7788186, 272211)
# remove image (last accessed time, image id) = (1587251538.2601352, 126371)
# remove image (last accessed time, image id) = (1587229862.236766, 101094)
# remove image (last accessed time, image id) = (1587222108.14841, 484964)
# remove image (last accessed time, image id) = (1587256319.6548057, 394209)
# remove image (last accessed time, image id) = (1587256318.7162404, 525104)
# remove image (last accessed time, image id) = (1587233528.1987374, 520000)
# remove image (last accessed time, image id) = (1587233527.713742, 376047)
# remove image (last accessed time, image id) = (1587224696.5039017, 487851)
# remove image (last accessed time, image id) = (1587252062.0396352, 520341)
# remove image (last accessed time, image id) = (1587232491.606932, 418811)
# remove image (last accessed time, image id) = (1587233008.4898922, 134420)
# remove image (last accessed time, image id) = (1587236203.8860452, 239754)
# remove image (last accessed time, image id) = (1587245254.1356142, 119015)
# remove image (last accessed time, image id) = (1587231449.5340028, 496306)
# remove image (last accessed time, image id) = (1587224181.0480237, 225360)
# remove image (last accessed time, image id) = (1587249443.851025, 64417)
# remove image (last accessed time, image id) = (1587243681.6869884, 510540)
# remove image (last accessed time, image id) = (1587250491.6745048, 256447)
# remove image (last accessed time, image id) = (1587224181.7293074, 225516)
# remove image (last accessed time, image id) = (1587248392.1919837, 515896)
# remove image (last accessed time, image id) = (1587243681.2927783, 510456)
# remove image (last accessed time, image id) = (1587229862.0355563, 363194)
# remove image (last accessed time, image id) = (1587256318.428236, 262897)
# remove image (last accessed time, image id) = (1587233529.139012, 105545)
# remove image (last accessed time, image id) = (1587228308.9065166, 230238)
# remove image (last accessed time, image id) = (1587226252.8483546, 540056)
# remove image (last accessed time, image id) = (1587229863.1783066, 232375)
# remove image (last accessed time, image id) = (1587221010.2907326, 483952)
# remove image (last accessed time, image id) = (1587227804.8072276, 229787)
# remove image (last accessed time, image id) = (1587235124.629868, 127104)
# remove image (last accessed time, image id) = (1587241022.4623194, 435897)
# remove image (last accessed time, image id) = (1587236202.2453227, 219196)
# remove image (last accessed time, image id) = (1587230390.140134, 494980)
# remove image (last accessed time, image id) = (1587228308.7035103, 361255)
# remove image (last accessed time, image id) = (1587247340.8772264, 252799)
# remove image (last accessed time, image id) = (1587256861.3813062, 525884)
# remove image (last accessed time, image id) = (1587254781.688411, 152722)
# remove image (last accessed time, image id) = (1587254238.8677075, 82873)
# remove image (last accessed time, image id) = (1587249968.93842, 151859)
# remove image (last accessed time, image id) = (1587245253.9151106, 512186)
# remove image (last accessed time, image id) = (1587223137.9450853, 224244)
# remove image (last accessed time, image id) = (1587222108.3087718, 474049)
# remove image (last accessed time, image id) = (1587250492.719191, 125575)
# remove image (last accessed time, image id) = (1587221010.3247313, 58815)
# remove image (last accessed time, image id) = (1587236202.9854414, 501718)
# remove image (last accessed time, image id) = (1587257396.410976, 132972)
# remove image (last accessed time, image id) = (1587232492.0236244, 104127)
# remove image (last accessed time, image id) = (1587243682.1265478, 248476)
# remove image (last accessed time, image id) = (1587252062.1993182, 520378)
# remove image (last accessed time, image id) = (1587255788.7539937, 524338)
# remove image (last accessed time, image id) = (1587223658.8037174, 386973)
# remove image (last accessed time, image id) = (1587251538.0559375, 519554)
# remove image (last accessed time, image id) = (1587252063.4979415, 237841)
# remove image (last accessed time, image id) = (1587245779.432709, 382069)
# remove image (last accessed time, image id) = (1587256859.493132, 263377)
# remove image (last accessed time, image id) = (1587247871.7765217, 122436)
# remove image (last accessed time, image id) = (1587257395.9635973, 526085)
# remove image (last accessed time, image id) = (1587253697.5370333, 260126)
# remove image (last accessed time, image id) = (1587251538.3154016, 519601)
# remove image (last accessed time, image id) = (1587230917.428973, 25121)
# remove image (last accessed time, image id) = (1587256318.742861, 131894)
# remove image (last accessed time, image id) = (1587245253.892729, 522270)
# remove image (last accessed time, image id) = (1587252586.6610215, 520765)
# remove image (last accessed time, image id) = (1587232493.2338471, 497616)
# remove image (last accessed time, image id) = (1587226252.6296732, 96660)
# remove image (last accessed time, image id) = (1587224697.3190465, 488002)
# remove image (last accessed time, image id) = (1587249970.409025, 256105)
# remove image (last accessed time, image id) = (1587232492.5569942, 284386)
# remove image (last accessed time, image id) = (1587230917.9777234, 257339)
# remove image (last accessed time, image id) = (1587244205.7550354, 511191)
# remove image (last accessed time, image id) = (1587231450.182038, 234293)
# remove image (last accessed time, image id) = (1587254782.7588422, 523318)
# remove image (last accessed time, image id) = (1587244206.0575879, 194437)
# remove image (last accessed time, image id) = (1587253149.3537958, 390559)
# remove image (last accessed time, image id) = (1587244203.9442012, 510813)
# remove image (last accessed time, image id) = (1587248391.9734485, 332912)
# remove image (last accessed time, image id) = (1587244731.8187428, 305105)
# remove image (last accessed time, image id) = (1587251538.7239158, 581089)
# remove image (last accessed time, image id) = (1587247339.1810236, 252470)
# remove image (last accessed time, image id) = (1587253149.640359, 128475)
# remove image (last accessed time, image id) = (1587242622.5541284, 303330)
# remove image (last accessed time, image id) = (1587254781.9859757, 392099)
# remove image (last accessed time, image id) = (1587238893.4683948, 111694)
# remove image (last accessed time, image id) = (1587241552.5641854, 115087)
# remove image (last accessed time, image id) = (1587236202.946958, 409513)
# remove image (last accessed time, image id) = (1587242621.8288753, 509110)
# remove image (last accessed time, image id) = (1587229341.2994337, 362568)
# remove image (last accessed time, image id) = (1587229341.282361, 231492)
# remove image (last accessed time, image id) = (1587247870.9854612, 122263)
# remove image (last accessed time, image id) = (1587253148.9614768, 521560)
# remove image (last accessed time, image id) = (1587234054.402841, 236093)
# remove image (last accessed time, image id) = (1587240487.3846807, 113205)
# remove image (last accessed time, image id) = (1587255326.2645676, 130972)
# remove image (last accessed time, image id) = (1587229341.1939065, 100395)
# remove image (last accessed time, image id) = (1587226252.1866305, 227635)
# remove image (last accessed time, image id) = (1587246814.2836807, 121052)
# remove image (last accessed time, image id) = (1587244203.6649349, 248610)
# remove image (last accessed time, image id) = (1587247340.4458544, 211927)
# remove image (last accessed time, image id) = (1587247872.4332185, 515796)
# remove image (last accessed time, image id) = (1587247870.351797, 253212)
# remove image (last accessed time, image id) = (1587255326.2831728, 262049)
# remove image (last accessed time, image id) = (1587230918.7877598, 497662)
# remove image (last accessed time, image id) = (1587225220.5246375, 95793)
# remove image (last accessed time, image id) = (1587251015.6039, 414202)
# remove image (last accessed time, image id) = (1587247872.3243022, 404095)
# remove image (last accessed time, image id) = (1587247870.3296177, 484875)
# remove image (last accessed time, image id) = (1587257398.2246573, 22222)
# remove image (last accessed time, image id) = (1587223137.6641598, 557394)
# remove image (last accessed time, image id) = (1587234594.39731, 389180)
# remove image (last accessed time, image id) = (1587243156.1021304, 247921)
# remove image (last accessed time, image id) = (1587252061.274832, 258073)
# remove image (last accessed time, image id) = (1587224698.6209292, 357202)
# remove image (last accessed time, image id) = (1587247871.7670338, 369931)
# remove image (last accessed time, image id) = (1587235123.2491708, 335859)
# remove image (last accessed time, image id) = (1587249968.5528157, 392145)
# remove image (last accessed time, image id) = (1587229342.8955762, 231851)
# remove image (last accessed time, image id) = (1587232493.4141176, 104435)
# remove image (last accessed time, image id) = (1587230390.6501355, 232919)
# remove image (last accessed time, image id) = (1587245255.8951197, 512572)
# remove image (last accessed time, image id) = (1587237817.4436975, 241076)
# remove image (last accessed time, image id) = (1587242623.364569, 509442)
# remove image (last accessed time, image id) = (1587238352.206669, 110761)
# remove image (last accessed time, image id) = (1587242623.254628, 247269)
# remove image (last accessed time, image id) = (1587241549.7246914, 193709)
# remove image (last accessed time, image id) = (1587230390.4649484, 232890)
# remove image (last accessed time, image id) = (1587230919.1311004, 364618)
# remove image (last accessed time, image id) = (1587235665.8360374, 149078)
# remove image (last accessed time, image id) = (1587243680.7084339, 248187)
# remove image (last accessed time, image id) = (1587224181.5663235, 225479)
# remove image (last accessed time, image id) = (1587242082.9182813, 377666)
# remove image (last accessed time, image id) = (1587231450.2991402, 234316)
# remove image (last accessed time, image id) = (1587234592.6338027, 368647)
# remove image (last accessed time, image id) = (1587230919.4237745, 233617)
# remove image (last accessed time, image id) = (1587238893.7339067, 111754)
# remove image (last accessed time, image id) = (1587257943.9933174, 526796)
# remove image (last accessed time, image id) = (1587231978.1392212, 365575)
# remove image (last accessed time, image id) = (1587246295.171632, 513643)
# remove image (last accessed time, image id) = (1587231450.2381701, 103230)
# remove image (last accessed time, image id) = (1587222627.4482915, 92702)
# remove image (last accessed time, image id) = (1587238354.0886762, 373292)
# remove image (last accessed time, image id) = (1587233010.468384, 452861)
# remove image (last accessed time, image id) = (1587227297.6272397, 97871)
# remove image (last accessed time, image id) = (1587247339.9538648, 121559)
# remove image (last accessed time, image id) = (1587230919.4411733, 102546)
# remove image (last accessed time, image id) = (1587251015.1386654, 64659)
# remove image (last accessed time, image id) = (1587243682.211523, 392352)
# remove image (last accessed time, image id) = (1587248913.9907646, 123366)
# remove image (last accessed time, image id) = (1587230918.3777688, 102320)
# remove image (last accessed time, image id) = (1587222627.4214709, 485913)
# remove image (last accessed time, image id) = (1587223658.0369673, 93441)
# remove image (last accessed time, image id) = (1587230917.5471215, 519465)
# remove image (last accessed time, image id) = (1587252062.1539826, 47879)
# remove image (last accessed time, image id) = (1587236202.3941967, 370524)
# remove image (last accessed time, image id) = (1587238351.785603, 372824)
# remove image (last accessed time, image id) = (1587244729.1772647, 118188)
# remove image (last accessed time, image id) = (1587246814.836404, 514393)
# remove image (last accessed time, image id) = (1587244729.2976685, 380350)
# remove image (last accessed time, image id) = (1587235666.0350912, 501292)
# remove image (last accessed time, image id) = (1587251014.984675, 422301)
# remove image (last accessed time, image id) = (1587225735.8790572, 358085)
# remove image (last accessed time, image id) = (1587233008.403786, 235700)
# remove image (last accessed time, image id) = (1587244206.308476, 514581)
# remove image (last accessed time, image id) = (1587243682.0918922, 248471)
# remove image (last accessed time, image id) = (1587226252.0482574, 358674)
# remove image (last accessed time, image id) = (1587244731.9908314, 511965)
# remove image (last accessed time, image id) = (1587249441.7442827, 123909)
# remove image (last accessed time, image id) = (1587244729.5031524, 380395)
# remove image (last accessed time, image id) = (1587221560.2694654, 484384)
# remove image (last accessed time, image id) = (1587255325.3576245, 523968)
# remove image (last accessed time, image id) = (1587224698.8615065, 146926)
# remove image (last accessed time, image id) = (1587224181.2153592, 356474)
# remove image (last accessed time, image id) = (1587227298.5998836, 98085)
# remove image (last accessed time, image id) = (1587227297.1579056, 228832)
# remove image (last accessed time, image id) = (1587245255.8350816, 512561)
# remove image (last accessed time, image id) = (1587254238.116537, 260448)
# remove image (last accessed time, image id) = (1587234592.3185542, 237505)
# remove image (last accessed time, image id) = (1587248914.4545712, 516668)
# remove image (last accessed time, image id) = (1587232491.9492574, 104114)
# remove image (last accessed time, image id) = (1587241551.6405213, 245978)
# remove image (last accessed time, image id) = (1587240489.8388858, 56978)
# remove image (last accessed time, image id) = (1587239961.9682527, 506062)
# remove image (last accessed time, image id) = (1587234056.311868, 563839)
# remove image (last accessed time, image id) = (1587253696.3719456, 414683)
# remove image (last accessed time, image id) = (1587222107.4154367, 211874)
# remove image (last accessed time, image id) = (1587229861.3861096, 100918)
# remove image (last accessed time, image id) = (1587234592.3424854, 221770)
# remove image (last accessed time, image id) = (1587252587.7402637, 258819)
# remove image (last accessed time, image id) = (1587237275.156302, 18241)
# remove image (last accessed time, image id) = (1587238892.8078873, 69182)
# remove image (last accessed time, image id) = (1587242622.0252671, 378071)
# remove image (last accessed time, image id) = (1587245778.676074, 513006)
# remove image (last accessed time, image id) = (1587227804.8479953, 360869)
# remove image (last accessed time, image id) = (1587254784.1360607, 130394)
# remove image (last accessed time, image id) = (1587223659.8200145, 168558)
# remove image (last accessed time, image id) = (1587237818.9380822, 503500)
# remove image (last accessed time, image id) = (1587255326.291435, 524195)
# remove image (last accessed time, image id) = (1587235665.6472833, 173812)
# remove image (last accessed time, image id) = (1587233528.3696125, 367518)
# remove image (last accessed time, image id) = (1587253150.1224864, 545720)
# remove image (last accessed time, image id) = (1587248392.1761277, 384815)
# remove image (last accessed time, image id) = (1587255791.6508749, 262707)
# remove image (last accessed time, image id) = (1587245776.7128932, 19899)
# remove image (last accessed time, image id) = (1587234055.545065, 237137)
# remove image (last accessed time, image id) = (1587240490.3853068, 455881)
# remove image (last accessed time, image id) = (1587239432.2656112, 505507)
# remove image (last accessed time, image id) = (1587252586.5901518, 567389)
# remove image (last accessed time, image id) = (1587251015.6482105, 109629)
# remove image (last accessed time, image id) = (1587230390.1209438, 82495)
# remove image (last accessed time, image id) = (1587230389.8303273, 494911)
# remove image (last accessed time, image id) = (1587226253.789632, 490129)
# remove image (last accessed time, image id) = (1587248393.4265566, 385066)
# remove image (last accessed time, image id) = (1587225218.5859036, 95381)
# ...
# remove image (last accessed time, image id) = (1587229341.6690538, 231581)
# remove image (last accessed time, image id) = (1587255788.9140286, 393291)
# remove image (last accessed time, image id) = (1587228823.1857805, 411617)
# remove image (last accessed time, image id) = (1587251015.8901687, 545285)
# remove image (last accessed time, image id) = (1587259010.8333585, 528119)
# remove image (last accessed time, image id) = (1587260620.3039913, 8909)
# remove image (last accessed time, image id) = (1587247341.097683, 514988)
# remove image (last accessed time, image id) = (1587250492.8250005, 142680)
# remove image (last accessed time, image id) = (1587224698.3990388, 226075)
# remove image (last accessed time, image id) = (1587244203.8972824, 379733)
# remove image (last accessed time, image id) = (1587242082.2795339, 246446)
# remove image (last accessed time, image id) = (1587231449.199364, 365164)
# remove image (last accessed time, image id) = (1587227803.9857342, 229594)
# remove image (last accessed time, image id) = (1587252063.680311, 258544)
# remove image (last accessed time, image id) = (1587243682.3799272, 194638)
# remove image (last accessed time, image id) = (1587221560.9616714, 222408)
# remove image (last accessed time, image id) = (1587257397.5993211, 526433)
# remove image (last accessed time, image id) = (1587246295.2331755, 85610)
# remove image (last accessed time, image id) = (1587223137.1763687, 321338)
# remove image (last accessed time, image id) = (1587256859.5548642, 525533)
# remove image (last accessed time, image id) = (1587223138.66621, 277700)
# remove image (last accessed time, image id) = (1587262239.7606494, 531658)
# remove image (last accessed time, image id) = (1587257943.3963146, 2400)
# remove image (last accessed time, image id) = (1587252062.9948692, 514888)
# remove image (last accessed time, image id) = (1587246812.839607, 304110)
# remove image (last accessed time, image id) = (1587261683.76736, 268733)
# remove image (last accessed time, image id) = (1587256859.1104157, 1166)
# remove image (last accessed time, image id) = (1587245778.5112014, 512968)
# remove image (last accessed time, image id) = (1587253149.7459776, 521715)
# remove image (last accessed time, image id) = (1587260620.0625627, 5368)
# remove image (last accessed time, image id) = (1587238893.8043165, 504982)
# remove image (last accessed time, image id) = (1587234593.747918, 499959)
# remove image (last accessed time, image id) = (1587242621.4097703, 377955)
# remove image (last accessed time, image id) = (1587241022.2050521, 376492)
# remove image (last accessed time, image id) = (1587256861.6475942, 502719)
# remove image (last accessed time, image id) = (1587236203.025809, 501723)
# remove image (last accessed time, image id) = (1587260085.0758374, 529317)
# remove image (last accessed time, image id) = (1587251540.4327385, 520027)
# remove image (last accessed time, image id) = (1587260084.3006456, 267028)
# remove image (last accessed time, image id) = (1587227804.0305374, 229598)
# remove image (last accessed time, image id) = (1587225218.5781276, 95380)
# remove image (last accessed time, image id) = (1587232491.5108182, 170253)
# remove image (last accessed time, image id) = (1587241020.4421256, 113962)
# remove image (last accessed time, image id) = (1587238352.8726861, 407509)
# remove image (last accessed time, image id) = (1587227298.9984481, 98179)
# remove image (last accessed time, image id) = (1587236202.8436272, 518351)
# remove image (last accessed time, image id) = (1587253149.898275, 128539)
# remove image (last accessed time, image id) = (1587247341.3195734, 379405)
# remove image (last accessed time, image id) = (1587223138.0283911, 486410)
# remove image (last accessed time, image id) = (1587251015.7029285, 257013)
# remove image (last accessed time, image id) = (1587237817.5437222, 372165)
# remove image (last accessed time, image id) = (1587237820.2313044, 372673)
# remove image (last accessed time, image id) = (1587244731.740301, 511915)
# remove image (last accessed time, image id) = (1587244730.1918936, 511587)
# remove image (last accessed time, image id) = (1587227297.6192763, 491084)
# remove image (last accessed time, image id) = (1587241021.9303734, 376436)
# remove image (last accessed time, image id) = (1587257397.7515826, 264322)
# remove image (last accessed time, image id) = (1587259011.485813, 397184)
# remove image (last accessed time, image id) = (1587231449.1555095, 91926)
# remove image (last accessed time, image id) = (1587232491.4375844, 188712)
# remove image (last accessed time, image id) = (1587221559.758954, 353204)
# remove image (last accessed time, image id) = (1587233527.834218, 279689)
# remove image (last accessed time, image id) = (1587256860.6279416, 394666)
# remove image (last accessed time, image id) = (1587260620.3545365, 136493)
# remove image (last accessed time, image id) = (1587231448.2303157, 233902)
# remove image (last accessed time, image id) = (1587238354.182496, 18529)
# remove image (last accessed time, image id) = (1587227298.6814725, 229172)
# remove image (last accessed time, image id) = (1587242082.856834, 508725)
# remove image (last accessed time, image id) = (1587245778.2749472, 250777)
# remove image (last accessed time, image id) = (1587244206.0878067, 249125)
# remove image (last accessed time, image id) = (1587246294.9976182, 323774)
# remove image (last accessed time, image id) = (1587238892.6381297, 433647)
# remove image (last accessed time, image id) = (1587249969.3586068, 518025)
# remove image (last accessed time, image id) = (1587233009.6281748, 498114)
# remove image (last accessed time, image id) = (1587228824.077556, 356856)
# remove image (last accessed time, image id) = (1587222109.087575, 223014)
# remove image (last accessed time, image id) = (1587263342.0675068, 270534)
# remove image (last accessed time, image id) = (1587221009.03583, 36908)
# remove image (last accessed time, image id) = (1587261683.8532646, 268750)
# remove image (last accessed time, image id) = (1587247869.9579341, 384197)
# remove image (last accessed time, image id) = (1587246293.609332, 251165)
# remove image (last accessed time, image id) = (1587235664.114598, 500890)
# remove image (last accessed time, image id) = (1587230919.288997, 495731)
# remove image (last accessed time, image id) = (1587237276.0798955, 502860)
# remove image (last accessed time, image id) = (1587245777.459118, 512757)
# remove image (last accessed time, image id) = (1587237818.7966886, 110259)
# remove image (last accessed time, image id) = (1587231977.4081244, 365437)
# remove image (last accessed time, image id) = (1587256317.713938, 393844)
# remove image (last accessed time, image id) = (1587234591.956354, 237427)
# remove image (last accessed time, image id) = (1587258484.0854313, 66085)
# remove image (last accessed time, image id) = (1587255790.7944102, 436975)
# remove image (last accessed time, image id) = (1587249968.4564834, 570343)
# remove image (last accessed time, image id) = (1587253696.8896625, 283631)
# remove image (last accessed time, image id) = (1587243154.0458555, 378566)
# remove image (last accessed time, image id) = (1587251538.9453502, 126521)
# remove image (last accessed time, image id) = (1587251538.5774062, 519652)
# remove image (last accessed time, image id) = (1587262238.3186045, 138153)
# remove image (last accessed time, image id) = (1587234054.357167, 64627)
# remove image (last accessed time, image id) = (1587229341.6259735, 231572)
# remove image (last accessed time, image id) = (1587225218.1992486, 488510)
# remove image (last accessed time, image id) = (1587225735.8447506, 59679)
# remove image (last accessed time, image id) = (1587239963.295447, 375282)
# remove image (last accessed time, image id) = (1587239963.3779287, 564993)
# remove image (last accessed time, image id) = (1587250490.6340628, 42707)
# remove image (last accessed time, image id) = (1587247871.4458199, 384507)
# remove image (last accessed time, image id) = (1587225220.1457648, 357858)
# remove image (last accessed time, image id) = (1587262780.0053883, 532062)
# remove image (last accessed time, image id) = (1587255789.4551969, 524470)
# remove image (last accessed time, image id) = (1587261150.3469071, 241281)
# remove image (last accessed time, image id) = (1587237820.0111468, 110483)
# remove image (last accessed time, image id) = (1587252587.7888236, 520975)
# remove image (last accessed time, image id) = (1587255790.083109, 21895)
# remove image (last accessed time, image id) = (1587225736.2772093, 358172)
# remove image (last accessed time, image id) = (1587238892.2240546, 373575)
# remove image (last accessed time, image id) = (1587230391.4479156, 233110)
# remove image (last accessed time, image id) = (1587262238.9929698, 7205)
# remove image (last accessed time, image id) = (1587256318.4692225, 131833)
# remove image (last accessed time, image id) = (1587242082.0594616, 377476)
# remove image (last accessed time, image id) = (1587259548.162097, 397648)
# remove image (last accessed time, image id) = (1587235125.7432787, 238589)
# remove image (last accessed time, image id) = (1587254784.2435079, 109117)
# remove image (last accessed time, image id) = (1587233529.8762352, 498916)
# remove image (last accessed time, image id) = (1587261682.3669245, 268472)
# remove image (last accessed time, image id) = (1587251538.6044283, 279175)
# remove image (last accessed time, image id) = (1587257946.1271467, 133994)
# remove image (last accessed time, image id) = (1587236742.979159, 367743)
# remove image (last accessed time, image id) = (1587246813.6561592, 383048)
# remove image (last accessed time, image id) = (1587252588.32476, 127863)
# remove image (last accessed time, image id) = (1587227297.2317815, 278439)
# remove image (last accessed time, image id) = (1587247341.6957455, 252962)
# remove image (last accessed time, image id) = (1587229342.29825, 670)
# remove image (last accessed time, image id) = (1587262780.97473, 7946)
# remove image (last accessed time, image id) = (1587260621.8389666, 5703)
# remove image (last accessed time, image id) = (1587237275.667525, 371702)
# remove image (last accessed time, image id) = (1587235666.3750262, 136316)
# remove image (last accessed time, image id) = (1587257396.3936331, 1895)
# remove image (last accessed time, image id) = (1587256860.7799113, 263623)
# remove image (last accessed time, image id) = (1587233528.037813, 498525)
# remove image (last accessed time, image id) = (1587251016.8222473, 436092)
# remove image (last accessed time, image id) = (1587255789.17942, 127)
# remove image (last accessed time, image id) = (1587244204.1137662, 248712)
# remove image (last accessed time, image id) = (1587259546.853912, 4180)
# remove image (last accessed time, image id) = (1587238353.5575104, 504258)
# remove image (last accessed time, image id) = (1587239963.5025945, 244267)
# remove image (last accessed time, image id) = (1587239961.5865505, 505979)
# remove image (last accessed time, image id) = (1587260619.7658913, 398535)
# remove image (last accessed time, image id) = (1587226774.23913, 228260)
# remove image (last accessed time, image id) = (1587236202.7917554, 277431)
# remove image (last accessed time, image id) = (1587228309.3108923, 16543)
# remove image (last accessed time, image id) = (1587228823.385159, 99844)
# remove image (last accessed time, image id) = (1587237277.3075206, 240967)
# remove image (last accessed time, image id) = (1587251015.4212453, 388020)
# remove image (last accessed time, image id) = (1587238892.469841, 504699)
# remove image (last accessed time, image id) = (1587249443.9755166, 386537)
# remove image (last accessed time, image id) = (1587237818.9894218, 241364)
# remove image (last accessed time, image id) = (1587254784.0246928, 349408)
# remove image (last accessed time, image id) = (1587228308.246044, 99025)
# remove image (last accessed time, image id) = (1587239432.8664234, 243504)
# remove image (last accessed time, image id) = (1587226775.9499369, 359716)
# remove image (last accessed time, image id) = (1587257396.3739104, 264033)
# remove image (last accessed time, image id) = (1587244729.3598118, 249291)
# remove image (last accessed time, image id) = (1587228308.340599, 431569)
# remove image (last accessed time, image id) = (1587234054.1902604, 191197)
# remove image (last accessed time, image id) = (1587221009.7582755, 560131)
# remove image (last accessed time, image id) = (1587253698.5096576, 391401)
# remove image (last accessed time, image id) = (1587251538.4358406, 519628)
# remove image (last accessed time, image id) = (1587260619.54431, 46195)
# remove image (last accessed time, image id) = (1587224696.8923285, 365310)
# remove image (last accessed time, image id) = (1587237819.577448, 302389)
# remove image (last accessed time, image id) = (1587228822.6389902, 492882)
# remove image (last accessed time, image id) = (1587236201.6121955, 108200)
# remove image (last accessed time, image id) = (1587263342.9012387, 384362)
# remove image (last accessed time, image id) = (1587233529.4067776, 498813)
# remove image (last accessed time, image id) = (1587254781.8465078, 129926)
# remove image (last accessed time, image id) = (1587233009.3528202, 279616)
# remove image (last accessed time, image id) = (1587261150.188652, 268008)
# remove image (last accessed time, image id) = (1587242083.070182, 377694)
# remove image (last accessed time, image id) = (1587263341.2125254, 270373)
# remove image (last accessed time, image id) = (1587247872.1885257, 384659)
# remove image (last accessed time, image id) = (1587260621.1701343, 267731)
# remove image (last accessed time, image id) = (1587221560.3372235, 15197)
# remove image (last accessed time, image id) = (1587247871.6738913, 122411)
# remove image (last accessed time, image id) = (1587257398.430836, 440893)
# remove image (last accessed time, image id) = (1587239960.6757329, 521204)
# remove image (last accessed time, image id) = (1587241021.5327542, 376362)
# remove image (last accessed time, image id) = (1587230917.1858613, 102073)
# remove image (last accessed time, image id) = (1587255789.8481512, 262399)
# remove image (last accessed time, image id) = (1587222108.1214483, 282557)
# remove image (last accessed time, image id) = (1587230391.2588055, 233071)
# remove image (last accessed time, image id) = (1587230390.9964147, 495143)
# remove image (last accessed time, image id) = (1587231449.5488267, 365236)
# remove image (last accessed time, image id) = (1587228822.98905, 492967)
# remove image (last accessed time, image id) = (1587245777.1087732, 488440)
# remove image (last accessed time, image id) = (1587228822.8386528, 278763)
# remove image (last accessed time, image id) = (1587223138.009915, 93191)
# remove image (last accessed time, image id) = (1587239432.7378967, 191417)
# remove image (last accessed time, image id) = (1587256319.576156, 525265)
# After removing old items, len(image_data_buffer) =  20000
# image_data.shape = (2000, 70, 2048)
# qdata.shape = (2000, 25, 3200)
# adata.shape = (2000, 10, 3200)
# qtype_data.shape = (2000, 1, 65)
# qdata_train.shape =  (1600, 25, 3200)
# qdata_test.shape =  (400, 25, 3200)
# adata_train.shape =  (1600, 10, 3200)
# adata_test.shape =  (400, 10, 3200)
# media_data_train.shape =  (1600, 70, 2048)
# media_data_test.shape =  (400, 70, 2048)
# reload model from file
# Train on 1600 samples, validate on 400 samples
# Epoch 1/20
# 1600/1600 [==============================] - 28s 17ms/step - loss: 1.0163 - acc: 0.0792 - val_loss: 1.0529 - val_acc: 0.0766
# Epoch 2/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.9008 - acc: 0.0863 - val_loss: 1.0435 - val_acc: 0.0774
# Epoch 3/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.8564 - acc: 0.0902 - val_loss: 1.0547 - val_acc: 0.0773
# Epoch 4/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.8227 - acc: 0.0935 - val_loss: 1.0625 - val_acc: 0.0780
# Epoch 5/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.7992 - acc: 0.0958 - val_loss: 1.0821 - val_acc: 0.0762
# Epoch 6/20
#  540/1600 [=========>....................] - ETA: 15s - loss: 0.7894 - acc: 0.0981

# %%
# test the QG model
# load the trained model and test

from keras.models import load_model

filename = "qg_100_150_200_cpu_24hrs.model"
file_saved_model = os.path.join(output_path, filename)
model = load_model(file_saved_model)

# get some data and make prediction
qdata, adata, media_data = get_train_data_qam(0, 30)
questions_predicted = model.predict({'text': adata, 'media': media_data})

print ("questions_predicted.shape = ", questions_predicted.shape)
print ("type(questions_predicted) = ", type(questions_predicted))

print ("questions_predicted[0, :] = ", questions_predicted[0, :])

questions_text = list_matrices_to_list_texts(questions_predicted)
qdata_text = list_matrices_to_list_texts(qdata)
adata_text = list_matrices_to_list_texts(adata)
for i in range(len(qdata)):
  print("\nanswer: ", adata_text[i])
  print("given question: ", qdata_text[i])
  print ("predicted_question = ", questions_text[i])
# Out:
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# len(list_found) = 30, len(list_image_ids) = 30
# buffer (385) not filled up.
# image_data.shape = (30, 70, 2048)
# qdata.shape = (30, 25, 3200)
# adata.shape = (30, 10, 3200)
# qtype_data.shape = (30, 1, 65)
# questions_predicted.shape =  (30, 25, 3200)
# type(questions_predicted) =  <class 'numpy.ndarray'>
# questions_predicted[0, :] =  [[2.58950777e-10 1.84189318e-07 9.98575251e-06 ... 6.03744824e-14
#   7.32403572e-14 4.49432700e-13]
#  [1.30791944e-09 2.05657620e-04 1.38621044e-05 ... 8.29086660e-11
#   9.69836780e-11 3.26113803e-10]
#  [2.84407742e-09 4.67982190e-03 1.49858087e-01 ... 1.00914423e-08
#   8.00579869e-09 7.93053800e-09]
#  ...
#  [1.98415471e-08 1.44950211e-01 4.00337763e-02 ... 2.75154353e-08
#   1.18046195e-08 1.62848295e-08]
#  [2.00473327e-08 1.55325279e-01 2.89985389e-02 ... 2.89739610e-08
#   1.37513272e-08 1.67651333e-08]
#  [2.05099777e-08 1.50445327e-01 2.44095735e-02 ... 3.04458645e-08
#   1.28933602e-08 1.60420051e-08]]
#
# answer:  net REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is this photo taken looking through REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is they man behind out the made made of of REMOVEDTOKEN made of of REMOVEDTOKEN made of of of of of of of of
#
# answer:  pitcher REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what position is this man playing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is the position on the position doing the his doing the the doing position the doing position the doing the the doing in the
#
# answer:  orange REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what color is the players shirt REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what color is the tennis shirt the ball shirt the the ball shirt the man's ball of the ball coat in the ball shirt the
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is this man a professional baseball player REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the man in the the the the the the the the the the the the the the the the the the the the the
#
# answer:  white REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what color is the snow REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what color is the man's on the ground the the camera the the the the the camera the the camera the the the camera the
#
# answer:  skiing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is the person doing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is this this person engaging in the position doing in the catch catch doing in catch catch catch in catch catch catch catch catch
#
# answer:  red REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what color is the persons REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what color is the on the the jacket the the the the the jacket of the REMOVEDTOKEN jacket the the coat of the background coat
#
# answer:  frisbee REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is in the person's hand REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is the man holding in to far hand hand catch mouth hand catch hand catch hand catch hand catch hand mouth hand mouth hand
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the dog waiting REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a in the the the the the the the the the the the the the the the the the the the the the
#
# answer:  frisbee REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the dog looking at a tennis ball or frisbee REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is the man holding in to far hand hand catch mouth hand catch hand catch hand catch hand catch hand mouth hand mouth hand
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the sky blue REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a in the the the REMOVEDTOKEN the the the REMOVEDTOKEN the the REMOVEDTOKEN of the the REMOVEDTOKEN the the the of the the
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is there snow on the mountains REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a in the the the REMOVEDTOKEN the the the REMOVEDTOKEN the the REMOVEDTOKEN of the the REMOVEDTOKEN the the the of the the
#
# answer:  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is the white REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what brand of the is the the the the the the the the the the the the the the the the the the the the
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the window open REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  are these animals REMOVEDTOKEN sale on the of of the REMOVEDTOKEN of the the of of of the of of of of of of of
#
# answer:  white and purple REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what color is the toothbrush REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what color is the plate stems in in plate plate in the picture plate veggies in the plate plate in the picture plate in the
#
# answer:  brushing teeth REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is the child doing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what are these doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing doing
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is she brushing REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  are these animals REMOVEDTOKEN sale on the of of the REMOVEDTOKEN of the the of of of the of of of of of of of
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the man smiling REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a REMOVEDTOKEN on the the the the the the the the the the the the the the the the of the the the
#
# answer:  REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is the business man doing in the picture REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what type of the is the the the the the the the the the the the the the the the the the the the the
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  does his tie pair well with his suit REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a REMOVEDTOKEN on the the the the the the the the the the the the the the the the of the the the
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  does the man look happy REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a REMOVEDTOKEN on the the the the the the the the the the the the the the the the of the the the
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is this photo in color REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a REMOVEDTOKEN on the the the the the the the the the the the the the the the the of the the the
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  is the man wearing a plain tie REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a REMOVEDTOKEN on the the the the the the the the the the the the the the the the of the the the
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  judging from the dress was this taken in a REMOVEDTOKEN american country REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is this a the the the the the the the the the the the the the the the the the the the the the the
#
# answer:  black and white REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what colors are shown in this picture REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what color is the woman on the plane on the plane sitting the the bench driving the plane sitting the the bench driving the plane
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  are the men on the sidewalk REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a in the the the the the the the the the the the the the the the the the the the the the
#
# answer:  no REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  was this photo taken recently REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  is the a in the the the the the the the the the the the the the the the the the the the the the
#
# answer:  yes REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  does the guy have a tattoo REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  are the giraffes in the the of of of of of of of of of of of of of of of of of of of
#
# answer:  skateboard REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  what is this man riding on REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  what is the man standing on their feet hand their feet feet feet feet feet feet feet feet feet feet feet feet feet feet feet
#
# answer:  1 REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# given question:  how many tattoos can be seen on this man's body REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN REMOVEDTOKEN
# predicted_question =  how many giraffes giraffes are in this field camera facing facing camera camera camera camera camera camera camera camera camera camera camera camera camera camera

# %%
# beam search given a predicted text sequence
# reference: https://machinelearningmastery.com/beam-search-decoder-natural-language-processing/

from math import log
 
 # get the k best answer sequences regardless of lengths
def beam_search(one_seq, k):

  # sequences is to keep the best k candidates
	# sequences = [[list(), 1.0]]
	sequences = [[list(), 0]]

	# keep track of the impossible candidates to speed up the selection
	impossible_candidates = {}

	# do this for the length of one_seq so it won't take too long
	for l in range(len(one_seq)):
		all_candidates = {}
		# for each best candidate so far, add each word and compute the new combined log probabilities;
    # if there are 10 candidates (i.e. k=10) and 50 possible words, then there will be 10*50 = 500 candidates (before further reducing to k candidates)
		for i in range(len(sequences)):
			seq, score = sequences[i]
			# add the last selected candidates to candidates
			if seq:
				all_candidates[str(seq)] = sequences[i]

			# the next row for each surviving seq is different
			next_row_id = len(seq)
			next_row = one_seq[next_row_id]
			for j in range(len(next_row)):
        # construct a new candidate, and the log probability
				# candidate = [seq + [j], score + log(next_row[j])]
				# to avoid duplications

				# if NULLTOKEN is at the first word, then dont keep the sequence
				if next_row_id == 0 and j == NULLTOKEN_INDEX:
					continue

				c = seq + [j]
				key = str(c)
				if key in impossible_candidates:
					continue

				# to compute the score: log(a*b) = log(a) + log(b)
				if next_row[j] == 0:
					# if the probability is 0, then set it to a very small number
					score_added = log(0.0000000000000000001)
				else:
					score_added = log(next_row[j])
		 
				candidate = [c, score + score_added]
				if not key in all_candidates:
					all_candidates[key] = candidate

    
		# print ("len(all_candidates) = ", len(all_candidates))
		# if l == 0:
		#	print ("all_candidates = ", all_candidates)	
	 
	  # just need the values
		all_candidates_list = all_candidates.values()

		# in each step, order all candidates by score
		ordered = sorted(all_candidates_list, reverse = True, key=lambda element: element[1])
  
		# in each step, select the currently best k candidates
		sequences = ordered[:k]
		# the current kth candidates onward and their childrens should not be considered
		for c in ordered[k:]:
			impossible_candidates[str(c[0])] = 0
		# print ("len(impossible_candidates) = ", len(impossible_candidates))
	
	return sequences


 # After beam search, maybe some customized but reasonable rules can be used to further select answers:

 # 1. given a selected 10-word answer from the beam search,
 # it can be futher cut to 1-word, 2-word, .. and 10-word answers (all starting from the first word), each of which will have its own log probability.
 # the rationale is that the answer is expected to be short, so shorter answers should be sampled from a 10-word answer candidate.

 # 2. in addition, if a word is found repeated, then the answer can be chopped at the word.
 
 # 3. if the REMOVEDTOKEN is encoutered for 2 consecutive times, the answer can be chopped too.

# %%
# load the trained models
from keras.models import load_model
import numpy as np

filename = "ag_question_as_input_100_150_200_cpu_30hrs.model"
file_saved_model = os.path.join(output_path, filename)
model_ag1 = load_model(file_saved_model)
print ("model summary for AG when question text is input:")
print(model_ag1.summary())


filename = "ag_questionTypes_as_input_100_150_200_cpu_32hrs.model"
file_saved_model = os.path.join(output_path, filename)
model_ag2 = load_model(file_saved_model)
print ("model summary for AG when questionType is input:")
print(model_ag2.summary())

filename = "qg_100_150_200_cpu_32hrs.model"
file_saved_model = os.path.join(output_path, filename)
model_qg = load_model(file_saved_model)
print("model summary for QG:")
print(model_qg.summary())
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# model summary for AG when question text is input:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               (None, 25, 3200)     0
# __________________________________________________________________________________________________
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 250)          0           lstm_1[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 10, 250)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 10, 200)      360800      repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 10, 3200)     643200      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,643,800
# Trainable params: 3,643,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# model summary for AG when questionType is input:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               (None, 1, 65)        0
# __________________________________________________________________________________________________
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 100)          66400       text[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 250)          0           lstm_4[0][0]
#                                                                  lstm_5[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 10, 250)      0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 10, 200)      360800      repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 10, 3200)     643200      lstm_6[0][0]
# ==================================================================================================
# Total params: 2,389,800
# Trainable params: 2,389,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# model summary for QG:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               (None, 10, 3200)     0
# __________________________________________________________________________________________________
# media (InputLayer)              (None, 70, 2048)     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 100)          1320400     text[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 150)          1319400     media[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 250)          0           lstm_1[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 25, 250)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 25, 200)      360800      repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 25, 3200)     643200      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,643,800
# Trainable params: 3,643,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
## use the AG and QG models to obtain the combined score for each answer candidate

import numpy as np
from math import log

def get_scores_from_qg(qseq, questions_each_answer_candidate):
  scores = []
  for q in questions_each_answer_candidate:
    score = 0
    for i in range(len(qseq)):
      word_index = qseq[i]
      row = q[i]
      if row[word_index] == 0:
        score_added = log(0.0000000000000000001)
      else:
        score_added = log( row[word_index] )
      score += score_added

    scores.append(score)
  return scores

# combine with QG to get the final scores
def get_overall_scores_for_1_question(model_qg, answers_from_beam_search, media, question_ground_truth_seq, qtext_eg, SILENT):

  ans_candidates_seqs = []
  for a, a_score in answers_from_beam_search:
    ans_candidates_seqs.append(a)

  ans_candidates_texts = list_sequences_to_texts(ans_candidates_seqs)
  if not SILENT:
    print ("answers from beam search in texts:")
    for i in range(len(ans_candidates_texts)):
      print ("score: {}, answer:{}".format(answers_from_beam_search[i][1], ans_candidates_texts[i]))

  answers_scored_by_qg = []

  answer_candidates_onehot = format_answer_texts(ans_candidates_texts)

  media_data_repeat = np.array([media] * len(answer_candidates_onehot))

  questions_each_answer_candidate = model_qg.predict({'text': answer_candidates_onehot, 'media': media_data_repeat})

  if not SILENT:
    print ("question_ground_truth_seq = ", question_ground_truth_seq)

  questions_each_answer_texts = list_matrices_to_list_texts(questions_each_answer_candidate)
  # for i in range(len(questions_each_answer_texts)):
  #  print ("for answer candidate: '{}', the best question generated is: '{}'".format(ans_candidates_texts[i], questions_each_answer_texts[i]))

  if not SILENT:
    print ("\nquestion text: ", qtext_eg)
    print ("question seq: ", question_ground_truth_seq)
    print ("When this question text is the output of the model, the scores from qg for each answer candidate are:".format(qtext_eg))

  scores_from_qg = get_scores_from_qg(question_ground_truth_seq, questions_each_answer_candidate)
  if not SILENT:
    print ("scores_from_qg = ", scores_from_qg)

  answer_candidates_and_scores = []
  for i in range( len(ans_candidates_texts) ):
    score_ag = answers_from_beam_search[i][1]
    score_qg = scores_from_qg[i]
    score_combined = score_ag + score_qg
    answer_candidates_and_scores.append( (score_combined, score_ag, score_qg, ans_candidates_texts[i], ans_candidates_seqs[i]) )

  answer_candidates_and_scores.sort(reverse=True)

  return answer_candidates_and_scores

def get_answer_candidates_and_scores_for_1_question(model_ag, model_qg, data, answers_predicted, id_eg, SILENT):

  media_data = data['media_data']

  atexts_df = data['answer_texts']
  qtexts_df = data['question_texts']
  qseqs = data['question_seqs']

  # get candidate answers
  answers_from_beam_search = beam_search(answers_predicted[id_eg], NUM_CANDIDATE_ANSWERS)
  if not SILENT:
    print ("answers_from_beam_search = \n", answers_from_beam_search)

  ## now use the QG model to obtain the combined score for each answer candidate
  media = media_data[id_eg]
  question_ground_truth_seq = qseqs[id_eg]
  qtext_eg = qtexts_df.iloc[id_eg]
  answer_candidates_and_scores = get_overall_scores_for_1_question(model_qg, answers_from_beam_search, media, question_ground_truth_seq, qtext_eg, SILENT)

  if not SILENT:
    print ("given raw answer = ", atexts_df.iloc[id_eg])
    print ("\nThe final ranking of answer candidates:")
    for a in answer_candidates_and_scores:
      print (a)

  return answer_candidates_and_scores

def get_stats_1question(answer_candidates_and_scores, ground_truth_ans_seq):
  top1=False
  top5=False
  top10=False
  top20=False
  
  ground_truth = list(ground_truth_ans_seq)
  n = min(20, len(answer_candidates_and_scores))

  for i in range(n):
    ans_seq_candidate = answer_candidates_and_scores[i][4]
    if ans_seq_candidate == ground_truth:
      if i == 0:
        top1=top5=top10=top20=True
      elif i<5:
        top5=top10=top20=True
      elif i<10:
        top10=top20=True
      elif i<20:
        top20=True        
      # if the right answer is found, immediately break
      break

  return [top1, top5, top10, top20]

def get_prediction_accuracy(model_ag, model_qg, data, text_data, SILENT=True):

  adata = data['answer_data']
  media_data = data['media_data']
  qdata = data['question_data']

  atexts_df = data['answer_texts']
  qtexts_df = data['question_texts']
  qseqs = data['question_seqs']
  aseqs = data['answer_seqs']
  image_ids_df = data['media_ids']

  # get the answers predicted from AG model
  print ("len(text_data) = ", len(text_data))
  print ("len(media_data) = ", len(media_data))
  print ("len(qtexts_df) = ", len(qtexts_df))
  answers_predicted = model_ag.predict({'text': text_data, 'media': media_data})

  print ("answers_predicted.shape = ", answers_predicted.shape)

  qdata_text = list_matrices_to_list_texts(qdata)
  adata_text = list_matrices_to_list_texts(adata)

  n_questions = 0
  n_correct_top1 = 0
  n_correct_top5 = 0
  n_correct_top10 = 0
  n_correct_top20 = 0

  detailed = []

  for id_eg in range(len(text_data)):
    if not SILENT:
      print ("\nid_eg = ", id_eg)
      print ("qdata_text = ", qdata_text[id_eg])
      print ("qdata raw text = ", qtexts_df.iloc[id_eg])
      print ("given answer = ", adata_text[id_eg])
      print ("given raw answer = ", atexts_df.iloc[id_eg])
      print ("image id = ", image_ids_df.iloc[id_eg])

    answer_candidates_and_scores = get_answer_candidates_and_scores_for_1_question(model_ag, model_qg, data, answers_predicted, id_eg, SILENT)
    intop1, intop5, intop10, intop20 = get_stats_1question(answer_candidates_and_scores, aseqs[id_eg])

    n_questions +=1
    n_correct_top1 += intop1
    n_correct_top5 += intop5
    n_correct_top10 += intop10
    n_correct_top20 += intop20
    detailed.append([int(intop1), int(intop5), int(intop10), int(intop20)])

  return [n_questions, n_correct_top1, n_correct_top5, n_correct_top10, n_correct_top20, detailed]

# %%
# Compute some metrics to evaluate the model
import os
import datetime

# choose the AG model
text_input = 'qtext'
#text_input = 'qtype'

file_results_summary = os.path.join( output_path , "{}_results_summary.csv".format(text_input) )
file_results_detailed = os.path.join( output_path ,"{}_results_detailed.csv".format(text_input) )

fsummary = open(file_results_summary, 'a')
fdetailed = open(file_results_detailed, 'a')

ndata = len(qa_df)

size = 2000

n_rounds_for_1_pass = int(ndata/size)
print ("n_rounds_for_1_pass = ", n_rounds_for_1_pass)

train_data_ratio = 0.8
test_data_start = int(size * train_data_ratio)

n_questions_total = ntop1_total = ntop5_total = ntop10_total = ntop20_total = 0

# control from which round to start
start_round = 3

# fetch data section by section so that it won't use up all the ram
for i in range(start_round, n_rounds_for_1_pass):
  print ("running round ", i)

  start = i * size

  # make sure validation data is the same after 1 pass of the whole data
  assert(start < ndata)

  print ("start: {} (total data = {})".format(start, ndata))

  # start_v = 0
  # end_v = 10
  # data = get_train_data(start_v, end_v)

  # only get test data
  start_v = start + test_data_start
  end_v = start+size
  data = get_train_data(start_v, end_v)
  len_data = len(data['question_data'])
  if (len_data != end_v - start_v ):
    print ("Length of data not correct. Better ignore this section of data")
    continue

  qtype_text_df = data['questionType_texts']

  # data = get_train_data(start + test_data_start, start + test_data_start+5)

  start = start + size


  print ("len(data['question_data']) = ", len(data['question_data']))

  if text_input == 'qtext':
    text_data = data['question_data']
    model_ag = model_ag1
  elif text_input == 'qtype':
    text_data = data['questionType_data']
    model_ag = model_ag2

  # run the function
  print ("time start for this round: ", datetime.datetime.now())
  n_questions, ntop1, ntop5, ntop10, ntop20, detailed = get_prediction_accuracy(model_ag, model_qg, data, text_data)
  print ("time end for this round: ", datetime.datetime.now())

  print ("n_questions = ", n_questions)
  print ("ntop1 = ", ntop1)
  print ("ntop5 = ", ntop5)
  print ("ntop10 = ", ntop10)
  print ("ntop20 = ", ntop20)

  assert(n_questions == len(data['question_data']))

  n_questions_total+=n_questions
  ntop1_total+=ntop1
  ntop5_total+=ntop5
  ntop10_total+=ntop10
  ntop20_total+=ntop20

  print ("n_questions_total = ", n_questions_total)
  print ("ntop1_total = ", ntop1_total)
  print ("ntop5_total = ", ntop5_total)
  print ("ntop10_total = ", ntop10_total)
  print ("ntop20_total = ", ntop20_total)

  fsummary.write("{},{},{},{},{}\n".format(n_questions_total, ntop1_total, ntop5_total, ntop10_total, ntop20_total))
  fsummary.flush()

  for i in range(start_v, end_v):
    # row id in the data, question_type, top1, top5, top10, top20
    j = i-start_v
    fdetailed.write("{},{},{},{},{},{}\n".format(i, qtype_text_df.iloc[j], detailed[j][0], detailed[j][1], detailed[j][2], detailed[j][3]))

  fdetailed.flush()
# Out:
# Streaming output truncated to the last 5000 lines.
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 05:02:46.951115
# n_questions =  400
# ntop1 =  53
# ntop5 =  104
# ntop10 =  133
# ntop20 =  164
# n_questions_total =  1200
# ntop1_total =  165
# ntop5_total =  309
# ntop10_total =  398
# ntop20_total =  481
# running round  6
# start: 12000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (310) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 05:02:48.568835
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 05:52:14.223444
# n_questions =  400
# ntop1 =  52
# ntop5 =  99
# ntop10 =  144
# ntop20 =  182
# n_questions_total =  1600
# ntop1_total =  217
# ntop5_total =  408
# ntop10_total =  542
# ntop20_total =  663
# running round  7
# start: 14000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (388) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 05:52:16.028113
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 06:39:53.797771
# n_questions =  400
# ntop1 =  58
# ntop5 =  109
# ntop10 =  140
# ntop20 =  174
# n_questions_total =  2000
# ntop1_total =  275
# ntop5_total =  517
# ntop10_total =  682
# ntop20_total =  837
# running round  8
# start: 16000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (466) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 06:39:55.730834
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 07:29:38.276722
# n_questions =  400
# ntop1 =  56
# ntop5 =  105
# ntop10 =  140
# ntop20 =  172
# n_questions_total =  2400
# ntop1_total =  331
# ntop5_total =  622
# ntop10_total =  822
# ntop20_total =  1009
# running round  9
# start: 18000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (540) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 07:29:40.025964
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# ...
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 13:15:06.132903
# n_questions =  400
# ntop1 =  46
# ntop5 =  90
# ntop10 =  137
# ntop20 =  175
# n_questions_total =  5200
# ntop1_total =  725
# ntop5_total =  1354
# ntop10_total =  1782
# ntop20_total =  2164
# running round  16
# start: 32000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (1066) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 13:15:08.437082
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# time end for this round:  2020-04-23 14:03:46.756904
# n_questions =  400
# ntop1 =  55
# ntop5 =  102
# ntop10 =  135
# ntop20 =  171
# n_questions_total =  5600
# ntop1_total =  780
# ntop5_total =  1456
# ntop10_total =  1917
# ntop20_total =  2335
# running round  17
# start: 34000 (total data = 443757)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(list_found) = 400, len(list_image_ids) = 400
# buffer (1133) not filled up.
# image_data.shape = (400, 70, 2048)
# qdata.shape = (400, 25, 3200)
# adata.shape = (400, 10, 3200)
# qtype_data.shape = (400, 1, 65)
# len(data['question_data']) =  400
# time start for this round:  2020-04-23 14:03:48.797270
# len(text_data) =  400
# len(media_data) =  400
# len(qtexts_df) =  400
# answers_predicted.shape =  (400, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)
# adata.shape = (50, 10, 3200)

# %%
# demo with some data

# choose the AG model
#text_input = 'qtext'
text_input = 'qtype'

# get some data and make prediction 
data = get_train_data(5693, 5700)
print ("len(data['question_data']) = ", len(data['question_data']))

if text_input == 'qtext':
  text_data = data['question_data']
  model_ag = model_ag1
elif text_input == 'qtype':
  text_data = data['questionType_data']
  model_ag = model_ag2

# run the function
n_questions, ntop1, ntop5, ntop10, ntop20, detailed = get_prediction_accuracy(model_ag, model_qg, data, text_data, False)

print ("n_questions = ", n_questions)
print ("ntop1 = ", ntop1)
print ("ntop5 = ", ntop5)
print ("ntop10 = ", ntop10)
print ("ntop20 = ", ntop20)
# Out:
# qdata.shape = (7, 25, 3200)
# adata.shape = (7, 10, 3200)
# qtype_data.shape = (7, 1, 65)
# len(list_found) = 7, len(list_image_ids) = 7
# buffer (19) not filled up.
# image_data.shape = (7, 70, 2048)
# qdata.shape = (7, 25, 3200)
# adata.shape = (7, 10, 3200)
# qtype_data.shape = (7, 1, 65)
# len(data['question_data']) =  7
# len(text_data) =  7
# len(media_data) =  7
# len(qtexts_df) =  7
# answers_predicted.shape =  (7, 10, 3200)
#
# id_eg =  0
# qdata_text =  what sport is being played NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# qdata raw text =  What sport is being played?
# given answer =  tennis NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# given raw answer =  tennis
# image id =  524559
# answers_from_beam_search =
#  [[[100], -1.0818179824521976], [[100, 452], -1.0967492382101245], [[217], -1.3356021098256092], [[217, 452], -1.350533365583536], [[134], -1.533020402520824], [[134, 452], -1.547951658278751], [[100, 452, 1202], -1.6639828614894798], [[217, 452, 1202], -1.9177669888628914], [[134, 452, 1202], -2.115185281558106], [[155], -2.2005313611845687], [[155, 452], -2.215462616942496], [[100, 452, 1202, 452], -2.3507247423073947], [[100, 452, 1202, 24], -2.364060931904329], [[100, 452, 1202, 452, 634], -2.4815395403506524], [[100, 452, 1202, 24, 634], -2.4948757299475868], [[217, 452, 1202, 452], -2.604508869680806], [[217, 452, 1202, 24], -2.617845059277741], [[100, 452, 1202, 452, 634, 452], -2.6800556915897085], [[100, 452, 1202, 24, 634, 452], -2.693391881186643], [[217, 452, 1202, 452, 634], -2.7353236677240638], [[217, 452, 1202, 24, 634], -2.7486598573209986], [[155, 452, 1202], -2.782696240221851], [[100, 452, 141], -2.7937130534825956], [[134, 452, 1202, 452], -2.8019271623760207], [[134, 452, 1202, 24], -2.8152633519729555], [[134, 452, 1202, 452, 634], -2.9327419604192784], [[217, 452, 1202
# answers from beam search in texts:
# score: -0.48539891657484946, answer:no
# score: -1.0114381297421355, answer:yes
# score: -1.0912283296746215, answer:no game
# score: -1.6172675428419077, answer:yes game
# score: -1.866054394264224, answer:no woman
# score: -1.8983689939552058, answer:no game game
# score: -2.39209360743151, answer:yes woman
# score: -2.4198686282416566, answer:no game no
# score: -2.4244082071224917, answer:yes game game
# score: -2.6731950585448083, answer:no woman game
# score: -2.7683766247253, answer:no game game game
# score: -2.9459078414089426, answer:yes game no
# score: -2.9781898670825977, answer:no game game game NULLTOKEN
# score: -3.062962799945691, answer:no game game NULLTOKEN
# score: -3.0972977934003842, answer:no game yes
# score: -3.1386449730493, answer:no man
# score: -3.194694692831259, answer:no woman no
# score: -3.1992342717120943, answer:yes woman game
# score: -3.272776042302989, answer:no game game NULLTOKEN NULLTOKEN
# score: -3.2898762590117507, answer:no game no game
# score: -3.294415837892586, answer:yes game game game
# score: -3.335373044201799, answer:no game game game NULLTOKEN NULLTOKEN
# score: -3.4060136467084026, answer:no game NULLTOKEN
# score: -3.4251445406632044, answer:no game game game NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.4996895013690485, answer:no game no game NULLTOKEN
# score: -3.5042290802498837, answer:yes game game game NULLTOKEN
# score: -3.5432026893149025, answer:no woman game game
# score: -3.5535071165505645, answer:no game game game NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.584462434232142, answer:no game no NULLTOKEN
# score: -3.589002013112977, answer:yes game game NULLTOKEN
# score: -3.62333700656767, answer:yes game yes
# score: -3.62995921942219, answer:no game game NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.6646841862165864, answer:yes man
# score: -3.6913977736535877, answer:no game game game NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.7197307158835957, answer:no game game NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.720733905998545, answer:yes woman no
# score: -3.7530159316722003, answer:no woman game game NULLTOKEN
# score: -3.79427567658944, answer:no game no NULLTOKEN NULLTOKEN
# score: -3.798815255470275, answer:yes game game NULLTOKEN NULLTOKEN
# score: -3.8159154721790367, answer:yes game no game
# score: -3.8377888645352938, answer:no woman game NULLTOKEN
# score: -3.848093291770956, answer:no game game NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.8568726784882497, answer:no game no game NULLTOKEN NULLTOKEN
# score: -3.8614122573690848, answer:yes game game game NULLTOKEN NULLTOKEN
# score: -3.872123857989987, answer:no woman yes
# score: -3.9144802916741166, answer:no game game game NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.9320528598756885, answer:yes game NULLTOKEN
# score: -3.9457856373298843, answer:no man game
# score: -3.9466441749496552, answer:no game no game NULLTOKEN NULLTOKEN NULLTOKEN
# score: -3.9511837538304904, answer:yes game game game NULLTOKEN NULLTOKEN NULLTOKEN
# adata.shape = (50, 10, 3200)
# question_ground_truth_seq =  [3, 6, 12, 775, 56]
#
# question text:  Is this a normal train?
# question seq:  [3, 6, 12, 775, 56]
# When this question text is the output of the model, the scores from qg for each answer candidate are:
], [[81, 44, 22, 22, 22], -3.430291120950429], [[40, 44, 22, 22, 22], -3.4446763507673412], [[152, 44, 22, 76], -3.467406870599097], [[38, 44, 22, 22, 22], -3.47791761221065], [[81, 44, 22, 76, 22], -3.4943932657004635], [[22, 44, 22, 22, 22], -3.5069093525087283], [[40, 44, 22, 76, 22], -3.5087784955173755], [[38, 44, 22, 76, 22], -3.542019756960684], [[22, 44, 22, 76, 22], -3.5710114972587625], [[152, 44, 22, 22, 22], -3.6466321562806114], [[152, 44, 22, 76, 22], -3.7107343010306457], [[81, 44, 22, 22, 22, 22], -3.7307375448516233], [[81, 44, 22, 22, 22, 22, 44], -3.73993101512229], [[40, 44, 22, 22, 22, 22], -3.7451227746685354], [[40, 44, 22, 22, 22, 22, 44], -3.754316244939202], [[38, 44, 22, 22, 22, 22], -3.778364036111844], [[36, 44, 22, 22], -3.7784934798820022]]
# answers from beam search in texts:
# score: -1.8846083532912028, answer:brown
# score: -1.8989935831081144, answer:blue
# score: -1.9322348445514232, answer:black
# score: -1.9612265848495016, answer:white
# score: -2.044501928795448, answer:brown and
# score: -2.05888715861236, answer:blue and
# score: -2.0921284200556687, answer:black and
# score: -2.100949388621385, answer:gray
# score: -2.121120160353747, answer:white and
# score: -2.2608429641256302, answer:gray and
# score: -2.412112354014428, answer:brown and white
# score: -2.42649758383134, answer:blue and white
# score: -2.4597388452746487, answer:black and white
# score: -2.4761381426543245, answer:red
# score: -2.488730585572727, answer:white and white
# score: -2.6284533893446103, answer:gray and white
# score: -2.6316786969858446, answer:yellow
# score: -2.63603171815857, answer:red and
# score: -2.79157227249009, answer:yellow and
# score: -2.7941961464530554, answer:green
# score: -2.954089721957301, answer:green and
# score: -3.00364214337755, answer:red and white
# score: -3.15918269770907, answer:yellow and white
# score: -3.1869636905188803, answer:brown and white white
# score: -3.2013489203357923, answer:blue and white white
# score: -3.234590181779101, answer:black and white white
# score: -3.2510658352689146, answer:brown and white yellow
# score: -3.2635819220771793, answer:white and white white
# score: -3.2654510650858266, answer:blue and white yellow
# score: -3.2986923265291352, answer:black and white yellow
# score: -3.321700147176281, answer:green and white
# score: -3.3276840668272136, answer:white and white yellow
# score: -3.4033047258490625, answer:gray and white white
# score: -3.430291120950429, answer:brown and white white white
# score: -3.4446763507673412, answer:blue and white white white
# score: -3.467406870599097, answer:gray and white yellow
# score: -3.47791761221065, answer:black and white white white
# score: -3.4943932657004635, answer:brown and white yellow white
# score: -3.5069093525087283, answer:white and white white white
# score: -3.5087784955173755, answer:blue and white yellow white
# score: -3.542019756960684, answer:black and white yellow white
# score: -3.5710114972587625, answer:white and white yellow white
# score: -3.6466321562806114, answer:gray and white white white
# score: -3.7107343010306457, answer:gray and white yellow white
# score: -3.7307375448516233, answer:brown and white white white white
# score: -3.73993101512229, answer:brown and white white white white and
# score: -3.7451227746685354, answer:blue and white white white white
# score: -3.754316244939202, answer:blue and white white white white and
# score: -3.778364036111844, answer:black and white white white white
# score: -3.7784934798820022, answer:red and white white
# adata.shape = (50, 10, 3200)
# (-8.881688035590164, -1.8846083532912028, -6.997079682298962, 'brown', [81])
# (-8.89274320538882, -3.4033047258490625, -5.489438479539758, 'gray and white white', [152, 44, 22, 22])
# (-8.979275985022051, -2.79157227249009, -6.187703712531961, 'yellow and', [76, 44])
# (-9.057943514784053, -3.6466321562806114, -5.411311358503442, 'gray and white white white', [152, 44, 22, 22, 22])
# (-9.21402479588675, -3.321700147176281, -5.892324648710469, 'green and white', [52, 44, 22])
# (-9.416097153140226, -2.05888715861236, -7.357209994527866, 'blue and', [40, 44])
# (-9.460091493363022, -2.0921284200556687, -7.367963073307353, 'black and', [38, 44])
# (-9.607831973712473, -3.754316244939202, -5.853515728773272, 'blue and white white white white and', [40, 44, 22, 22, 22, 22, 44])
# (-9.69267927875201, -2.044501928795448, -7.648177349956562, 'brown and', [81, 44])
# (-9.801741256101941, -3.5069093525087283, -6.294831903593213, 'white and white white white', [22, 44, 22, 22, 22])
# (-10.108595876683664, -3.15918269770907, -6.949413178974593, 'yellow and white', [76, 44, 22])
# (-10.908441658955017, -2.412112354014428, -8.496329304940588, 'brown and white', [81, 44, 22])
# (-11.589696287682802, -2.4597388452746487, -9.129957442408154, 'black and white', [38, 44, 22])
# (-11.602901104920088, -3.4943932657004635, -8.108507839219625, 'brown and white yellow white', [81, 44, 22, 76, 22])
# (-11.670163871754887, -3.2654510650858266, -8.40471280666906, 'blue and white yellow', [40, 44, 22, 76])
# (-11.708730333781856, -3.2510658352689146, -8.457664498512942, 'brown and white yellow', [81, 44, 22, 76])
# (-11.815438707615751, -3.1869636905188803, -8.628475017096871, 'brown and white white', [81, 44, 22, 22])
# (-11.992452760855022, -3.430291120950429, -8.562161639904593, 'brown and white white white', [81, 44, 22, 22, 22])
# (-12.067909750710793, -3.778364036111844, -8.28954571459895, 'black and white white white white', [38, 44, 22, 22, 22, 22])
# (-12.238313252680074, -3.2986923265291352, -8.939620926150939, 'black and white yellow', [38, 44, 22, 76])
# (-12.318721791728567, -3.5087784955173755, -8.809943296211191, 'blue and white yellow white', [40, 44, 22, 76, 22])
# (-12.863700000653255, -3.7307375448516233, -9.132962455801632, 'brown and white white white white', [81, 44, 22, 22, 22, 22])
# (-12.95715486859117, -3.542019756960684, -9.415135111630486, 'black and white yellow white', [38, 44, 22, 76, 22])
# (-13.069008346160924, -3.234590181779101, -9.834418164381823, 'black and white white', [38, 44, 22, 22])
# (-13.277525424539522, -3.73993101512229, -9.537594409417233, 'brown and white white white white and', [81, 44, 22, 22, 22, 22, 44])
# (-14.160550297586386, -3.7784934798820022, -10.382056817704385, 'red and white white', [36, 44, 22, 22])
# (-14.41233445573208, -3.00364214337755, -11.408692312354528, 'red and white', [36, 44, 22])
# (-15.39382235153813, -3.47791761221065, -11.91590473932748, 'black and white white white', [38, 44, 22, 22, 22])
# (-16.096821458649632, -2.63603171815857, -13.460789740491062, 'red and', [36, 44])
# n_questions =  7
# ntop1 =  2
# ntop5 =  4
# ntop10 =  4
# ntop20 =  5
