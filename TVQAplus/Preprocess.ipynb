# %%
#Mount gdrive and change directory to project location.
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/My Drive/cs6240 - media/vqa/TVQAplus/tvqa_plus_stage_features'

#Check CUDA availability
# !nvidia-smi
import torch
torch.cuda.is_available()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/cs6240 - media/vqa/TVQAplus/tvqa_plus_stage_features
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
# False

# %%
# %pip install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# %pip install --upgrade tqdm
# %pip install h5py numpy

# %%
# !python tvqa_small_dataset.py
# %cd tvqa_plus_stage_features/
# !ls
# !python tvqa_small_dataset.py
# %cd sample3
# !ls
# !cp eval_object_vocab.json /sample3
# !cp frm_cnt_cache.json /sample
# !cp frm_cnt_cache.json /sample3
# !cp tvqa_bbt_bottom_up_pool5_hq_20_100_pca.h5 /sample3

# %%
# %cd ..
# %cd '../tvqa_original_videos/tvqa_frames_hq (1)'
# !ls
# Out:
# /content/drive/My Drive/cs6240 - media/vqa/TVQAplus/tvqa_original_videos/tvqa_frames_hq (1)
# tvqa_video_frames_fps3_hq.checksum.txt	tvqa_video_frames_fps3_hq.tar.gz.ar
# tvqa_video_frames_fps3_hq.tar.gz.aa	tvqa_video_frames_fps3_hq.tar.gz.as
# tvqa_video_frames_fps3_hq.tar.gz.ab	tvqa_video_frames_fps3_hq.tar.gz.at
# tvqa_video_frames_fps3_hq.tar.gz.ac	tvqa_video_frames_fps3_hq.tar.gz.au
# tvqa_video_frames_fps3_hq.tar.gz.ad	tvqa_video_frames_fps3_hq.tar.gz.av
# tvqa_video_frames_fps3_hq.tar.gz.ae	tvqa_video_frames_fps3_hq.tar.gz.aw
# tvqa_video_frames_fps3_hq.tar.gz.af	tvqa_video_frames_fps3_hq.tar.gz.ax
# tvqa_video_frames_fps3_hq.tar.gz.ag	tvqa_video_frames_fps3_hq.tar.gz.ay
# tvqa_video_frames_fps3_hq.tar.gz.ah	tvqa_video_frames_fps3_hq.tar.gz.az
# tvqa_video_frames_fps3_hq.tar.gz.ai	tvqa_video_frames_fps3_hq.tar.gz.ba
# tvqa_video_frames_fps3_hq.tar.gz.aj	tvqa_video_frames_fps3_hq.tar.gz.bb
# tvqa_video_frames_fps3_hq.tar.gz.ak	tvqa_video_frames_fps3_hq.tar.gz.bc
# tvqa_video_frames_fps3_hq.tar.gz.al	tvqa_video_frames_fps3_hq.tar.gz.bd
# tvqa_video_frames_fps3_hq.tar.gz.am	tvqa_video_frames_fps3_hq.tar.gz.be
# tvqa_video_frames_fps3_hq.tar.gz.an	tvqa_video_frames_fps3_hq.tar.gz.bf
# tvqa_video_frames_fps3_hq.tar.gz.ao	tvqa_video_frames_fps3_hq.tar.gz.bg
# tvqa_video_frames_fps3_hq.tar.gz.ap	tvqa_video_frames_fps3_hq.tar.gz.bh
# tvqa_video_frames_fps3_hq.tar.gz.aq	tvqa_video_frames_fps3_hq.tar.gz.bi

# %%
# %mkdir frames
# !cat tvqa_video_frames_fps3_hq.tar.gz.* | tar xz -C frames
# Out:
# cat: tvqa_video_frames_fps3_hq.tar.gz.ad: Operation canceled

# %%
# !df -h .
