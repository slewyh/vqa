# %%
#Mount gdrive and change directory to project location.
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/My Drive/cs6240 - media/vqa/TVQAplus'

#Check CUDA availability
# !nvidia-smi
import torch
torch.cuda.is_available()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/cs6240 - media/vqa/TVQAplus
# Thu Apr 23 22:37:12 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# ...

# %% [markdown]
# **Install pre-requisites**
# Python 2.7
#
# *   PyTorch 1.1.0 (should work for 0.4.0 - 1.2.0)
# *   tensorboardX  (training progress visualizer)
# *   tqdm (progress bar)
# *   h5py
# *   numpy

# %%
# %pip install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# %pip install --upgrade tqdm
# %pip install h5py numpy
# Out:
# ...
#      |████████████████████████████████| 61kB 2.3MB/s
# ...
#   Found existing installation: tqdm 4.38.0
#     Uninstalling tqdm-4.38.0:
#       Successfully uninstalled tqdm-4.38.0
# ...

# %%
# %pip install tensorboardX==1.9
# %pip install tensorboard
# Out:
# ...
#      |████████████████████████████████| 194kB 3.4MB/s
# ...

# %%
#Test your enviroment with 5 training epochs.
# !ls
# !python dummy.py
# !bash run_main.sh debug

# %%
# %cd tvqa_plus_stage_features
# !python3 tvqa_small_dataset.py
# Out:
# [Errno 2] No such file or directory: 'tvqa_plus_stage_features'
# /content/drive/My Drive/cs6240 - media/vqa/TVQAplus/tvqa_plus_stage_features
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --logdir results/

# %%
#Train Full STAGE model
# !TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD=50000000000
# Debug version
# !bash run_main.sh debug
# With GPU version
# !bash run_main.sh  --no_core_driver --add_local
# With CPU only
# !bash run_main.sh --add_local --no_core_driver --device -1

# %%
# Run inference model
# %env MODEL_DIR=results_2020_04_19_02_47_45
# %env MODE=valid
# !bash run_inference.sh ${MODEL_DIR} ${MODE}
# Out:
# env: MODEL_DIR=results_2020_04_19_02_47_45
# env: MODE=valid

# %%
# %cd eval
# !python eval_tvqa_plus.py --pred_path ../results/${MODEL_DIR}/valid_inference_predictions.json --gt_path data/tvqa_plus_val.json
# Out:
# [Errno 2] No such file or directory: 'eval'
# /content/drive/My Drive/cs6240 - media/vqa/TVQAplus/eval
# ------------ Options -------------
# gt_path: data/tvqa_plus_val.json
# no_preproc_pred: False
# output_path: None
# pred_path: ../results/results_2020_04_19_02_47_45/valid_inference_predictions.json
# word2idx_path: data/word2idx.json
# -------------- End ----------------
# Start TVQAplus evaluation...
# QA Acc. 0.6
# Grd. mAP 0.0010755697978274423
# Temp. mIoU0.0649636915472118
# ASA 0.0
